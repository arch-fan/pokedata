# %% [markdown]
# # Download the JSON files

# %%
import requests
import json
import os
from concurrent.futures import ThreadPoolExecutor

# Create directory to save pokemons
os.makedirs("pokemons", exist_ok=True)

# Fetch data
url = "https://pokeapi.co/api/v2/pokemon?limit=100000&offset=0"
response = requests.get(url)
all_pkmns = response.json()
pokelist = all_pkmns['results']

def fetch_and_save_pokemon_data(pokemon):
    """Fetch and save pokemon data."""
    try:
        # URLs for species and pokemon data
        url_pokemon = pokemon['url']
        url_species = f"https://pokeapi.co/api/v2/pokemon-species/{pokemon['url'].split('/')[-2]}/"
        
        # Fetch data
        response_species = requests.get(url_species)
        response_pokemon = requests.get(url_pokemon)
        
        # Save data to JSON files
        data = {
            'species': response_species.json(),
            'pokemon': response_pokemon.json()
        }
        
        pkmn_id = data['pokemon']['id']
        
        with open(f"pokemons/{pkmn_id}-{pokemon['name']}.json", "w") as f:
            json.dump(data['pokemon'], f)
        
        with open(f"pokemons/{pkmn_id}-{pokemon['name']}-species.json", "w") as f:
            json.dump(data['species'], f)
        
        print(f"Saved {pkmn_id}-{pokemon['name']}")
    except Exception as e:
        print(f"Failed to fetch/save {pokemon['name']}: {e}")

# Use ThreadPoolExecutor for concurrency
with ThreadPoolExecutor(max_workers=10) as executor:
    # Submit tasks
    futures = [
        executor.submit(fetch_and_save_pokemon_data, p)
        for p in pokelist
    ]

    # Wait for all tasks to complete
    for future in futures:
        future.result()  # This will raise exceptions if any occurred

print("All data fetched and saved!")
# Out:
# Saved 1-bulbasaur
# Saved 2-ivysaur
# Saved 7-squirtle
# Saved 5-charmeleon
# Saved 10-caterpie
# Saved 9-blastoise
# Saved 12-butterfree
# Saved 3-venusaur
# Saved 8-wartortle
# Saved 4-charmander
# Saved 14-kakuna
# Saved 6-charizard
# Saved 16-pidgey
# Saved 17-pidgeotto
# Saved 11-metapod
# Saved 13-weedle
# Saved 18-pidgeot
# Saved 19-rattata
# Saved 15-beedrill
# Saved 21-spearow
# Saved 25-pikachu
# Saved 24-arbok
# Saved 23-ekans
# Saved 30-nidorina
# Saved 33-nidorino
# Saved 29-nidoran-f
# Saved 22-fearow
# Saved 20-raticate
# Saved 28-sandslash
# Saved 34-nidoking
# Saved 27-sandshrew
# Saved 32-nidoran-m
# Saved 39-jigglypuff
# Saved 31-nidoqueen
# Saved 42-golbat
# Saved 37-vulpix
# Saved 26-raichu
# Saved 38-ninetales
# Saved 46-paras
# Saved 48-venonat
# Saved 36-clefable
# Saved 35-clefairy
# Saved 40-wigglytuff
# Saved 49-venomoth
# Saved 41-zubat
# Saved 45-vileplume
# Saved 44-gloom
# Saved 43-oddish
# Saved 50-diglett
# Saved 53-persian
# Saved 51-dugtrio
# Saved 47-parasect
# Saved 52-meowth
# Saved 54-psyduck
# Saved 56-mankey
# Saved 58-growlithe
# Saved 59-arcanine
# Saved 62-poliwrath
# Saved 64-kadabra
# Saved 66-machop
# Saved 68-machamp
# Saved 60-poliwag
# Saved 57-primeape
# Saved 63-abra
# Saved 61-poliwhirl
# Saved 69-bellsprout
# Saved 72-tentacool
# Saved 71-victreebel
# Saved 67-machoke
# Saved 65-alakazam
# Saved 70-weepinbell
# Saved 78-rapidash
# Saved 55-golduck
# Saved 79-slowpoke
# Saved 80-slowbro
# Saved 75-gravelerSaved 74-geodude
#
# Saved 76-golem
# Saved 77-ponyta
# Saved 73-tentacruel
# Saved 90-shellder
# Saved 88-grimer
# Saved 81-magnemite
# Saved 82-magneton
# Saved 83-farfetchd
# Saved 85-dodrio
# Saved 84-doduo
# Saved 86-seel
# Saved 87-dewgong
# Saved 96-drowzee
# Saved 98-krabby
# Saved 91-cloyster
# Saved 89-muk
# Saved 92-gastly
# Saved 93-haunter
# Saved 100-voltorb
# Saved 99-kingler
# Saved 95-onix
# Saved 106-hitmonlee
# Saved 94-gengar
# Saved 101-electrode
# Saved 107-hitmonchan
# Saved 110-weezing
# Saved 103-exeggutor
# Saved 102-exeggcute
# Saved 104-cubone
# Saved 105-marowak
# Saved 97-hypno
# Saved 114-tangela
# Saved 116-horsea
# Saved 108-lickitung
# Saved 109-koffing
# Saved 117-seadra
# Saved 111-rhyhorn
# Saved 112-rhydon
# Saved 120-staryu
# Saved 113-chansey
# Saved 118-goldeen
# Saved 115-kangaskhan
# Saved 122-mr-mime
# Saved 127-pinsir
# Saved 128-tauros
# Saved 119-seaking
# Saved 129-magikarp
# Saved 130-gyarados
# Saved 121-starmie
# Saved 123-scyther
# Saved 124-jynx
# Saved 134-vaporeon
# Saved 125-electabuzz
# Saved 131-lapras
# Saved 126-magmar
# Saved 133-eevee
# Saved 141-kabutops
# Saved 139-omastar
# Saved 132-ditto
# Saved 136-flareon
# Saved 137-porygon
# Saved 135-jolteon
# Saved 145-zapdos
# Saved 138-omanyte
# Saved 140-kabuto
# Saved 142-aerodactyl
# Saved 143-snorlax
# Saved 151-mew
# Saved 144-articuno
# Saved 146-moltres
# Saved 153-bayleef
# Saved 156-quilava
# Saved 149-dragonite
# Saved 147-dratini
# Saved 148-dragonair
# Saved 150-mewtwo
# Saved 154-meganium
# Saved 157-typhlosion
# Saved 152-chikorita
# Saved 155-cyndaquil
# Saved 158-totodile
# Saved 159-croconaw
# Saved 164-noctowl
# Saved 160-feraligatr
# Saved 162-furret
# Saved 166-ledian
# Saved 165-ledyba
# Saved 163-hoothoot
# Saved 172-pichu
# Saved 167-spinarak
# Saved 171-lanturn
# Saved 170-chinchou
# Saved 161-sentret
# Saved 169-crobat
# Saved 173-cleffa
# Saved 168-ariados
# Saved 176-togetic
# Saved 177-natu
# Saved 182-bellossom
# Saved 186-politoed
# Saved 174-igglybuff
# Saved 178-xatu
# Saved 175-togepi
# Saved 183-marill
# Saved 180-flaaffy
# Saved 179-mareep
# Saved 185-sudowoodo
# Saved 193-yanma
# Saved 187-hoppip
# Saved 184-azumarill
# Saved 189-jumpluff
# Saved 191-sunkern
# Saved 181-ampharos
# Saved 188-skiploom
# Saved 192-sunflora
# Saved 194-wooper
# Saved 190-aipom
# Saved 201-unown
# Saved 198-murkrow
# Saved 195-quagsire
# Saved 196-espeon
# Saved 199-slowking
# Saved 197-umbreon
# Saved 200-misdreavus
# Saved 205-forretress
# Saved 203-girafarig
# Saved 210-granbull
# Saved 211-qwilfish
# Saved 202-wobbuffet
# Saved 213-shuckle
# Saved 204-pineco
# Saved 215-sneasel
# Saved 207-gligar
# Saved 218-slugma
# Saved 214-heracross
# Saved 209-snubbull
# Saved 208-steelix
# Saved 206-dunsparce
# Saved 212-scizor
# Saved 217-ursaring
# Saved 224-octillery
# Saved 216-teddiursa
# Saved 222-corsola
# Saved 227-skarmory
# Saved 229-houndoom
# Saved 219-magcargo
# Saved 220-swinub
# Saved 225-delibird
# Saved 221-piloswine
# Saved 231-phanpy
# Saved 226-mantine
# Saved 223-remoraid
# Saved 232-donphan
# Saved 234-stantler
# Saved 228-houndour
# Saved 230-kingdra
# Saved 235-smeargle
# Saved 236-tyrogue
# Saved 238-smoochum
# Saved 242-blissey
# Saved 241-miltank
# Saved 233-porygon2
# Saved 239-elekid
# Saved 249-lugia
# Saved 240-magby
# Saved 244-entei
# Saved 247-pupitar
# Saved 246-larvitar
# Saved 243-raikou
# Saved 255-torchic
# Saved 245-suicune
# Saved 250-ho-oh
# Saved 248-tyranitar
# Saved 252-treecko
# Saved 237-hitmontop
# Saved 256-combusken
# Saved 251-celebi
# Saved 263-zigzagoon
# Saved 259-marshtomp
# Saved 254-sceptile
# Saved 253-grovyle
# Saved 265-wurmple
# Saved 258-mudkip
# Saved 257-blaziken
# Saved 260-swampert
# Saved 261-poochyena
# Saved 262-mightyena
# Saved 266-silcoon
# Saved 270-lotad
# Saved 267-beautifly
# Saved 268-cascoon
# Saved 269-dustox
# Saved 264-linoone
# Saved 274-nuzleaf
# Saved 272-ludicolo
# Saved 276-taillow
# Saved 279-pelipper
# Saved 278-wingull
# Saved 281-kirlia
# Saved 277-swellow
# Saved 273-seedot
# Saved 283-surskit
# Saved 286-breloom
# Saved 271-lombre
# Saved 275-shiftry
# Saved 287-slakoth
# Saved 280-ralts
# Saved 282-gardevoir
# Saved 285-shroomish
# Saved 284-masquerain
# Saved 290-nincada
# Saved 297-hariyama
# Saved 293-whismur
# Saved 292-shedinja
# Saved 296-makuhita
# Saved 300-skitty
# Saved 291-ninjask
# Saved 298-azurill
# Saved 299-nosepass
# Saved 294-loudred
# Saved 289-slaking
# Saved 301-delcatty
# Saved 295-exploud
# Saved 288-vigoroth
# Saved 308-medicham
# Saved 302-sableye
# Saved 304-aron
# Saved 306-aggron
# Saved 315-roselia
# Saved 303-mawile
# Saved 309-electrike
# Saved 305-lairon
# Saved 316-gulpin
# Saved 310-manectric
# Saved 312-minun
# Saved 311-plusle
# Saved 313-volbeat
# Saved 307-meditite
# Saved 314-illumise
# Saved 319-sharpedo
# Saved 323-camerupt
# Saved 325-spoink
# Saved 317-swalot
# Saved 318-carvanha
# Saved 328-trapinch
# Saved 329-vibrava
# Saved 324-torkoal
# Saved 320-wailmer
# Saved 322-numel
# Saved 321-wailord
# Saved 326-grumpig
# Saved 327-spinda
# Saved 336-seviper
# Saved 334-altaria
# Saved 337-lunatone
# Saved 340-whiscash
# Saved 330-flygon
# Saved 338-solrock
# Saved 331-cacnea
# Saved 341-corphish
# Saved 332-cacturne
# Saved 333-swablu
# Saved 347-anorith
# Saved 335-zangoose
# Saved 346-cradily
# Saved 344-claydol
# Saved 350-milotic
# Saved 339-barboach
# Saved 342-crawdaunt
# Saved 345-lileep
# Saved 348-armaldo
# Saved 343-baltoy
# Saved 349-feebas
# Saved 351-castform
# Saved 360-wynaut
# Saved 358-chimecho
# Saved 354-banette
# Saved 353-shuppet
# Saved 355-duskull
# Saved 363-spheal
# Saved 359-absol
# Saved 365-walrein
# Saved 362-glalie
# Saved 356-dusclops
# Saved 357-tropius
# Saved 369-relicanth
# Saved 352-kecleon
# Saved 364-sealeo
# Saved 366-clamperl
# Saved 368-gorebyss
# Saved 367-huntail
# Saved 371-bagon
# Saved 370-luvdisc
# Saved 372-shelgon
# Saved 377-regirock
# Saved 361-snorunt
# Saved 373-salamence
# Saved 384-rayquaza
# Saved 374-beldum
# Saved 375-metang
# Saved 376-metagross
# Saved 388-grotle
# Saved 379-registeel
# Saved 386-deoxys-normal
# Saved 385-jirachi
# Saved 380-latias
# Saved 378-regice
# Saved 383-groudon
# Saved 382-kyogre
# Saved 381-latios
# Saved 391-monferno
# Saved 390-chimchar
# Saved 392-infernape
# Saved 393-piplup
# Saved 398-staraptor
# Saved 400-bibarel
# Saved 399-bidoof
# Saved 389-torterra
# Saved 396-starly
# Saved 387-turtwig
# Saved 395-empoleon
# Saved 403-shinx
# Saved 408-cranidos
# Saved 394-prinplup
# Saved 397-staravia
# Saved 401-kricketot
# Saved 407-roserade
# Saved 404-luxio
# Saved 411-bastiodon
# Saved 402-kricketune
# Saved 413-wormadam-plant
# Saved 410-shieldon
# Saved 416-vespiquen
# Saved 405-luxray
# Saved 406-budew
# Saved 420-cherubi
# Saved 423-gastrodon
# Saved 412-burmy
# Saved 421-cherrim
# Saved 414-mothim
# Saved 415-combee
# Saved 409-rampardos
# Saved 425-drifloon
# Saved 417-pachirisu
# Saved 424-ambipom
# Saved 426-drifblim
# Saved 419-floatzel
# Saved 422-shellos
# Saved 434-stunky
# Saved 431-glameow
# Saved 436-bronzor
# Saved 433-chingling
# Saved 418-buizel
# Saved 429-mismagius
# Saved 427-buneary
# Saved 430-honchkrow
# Saved 428-lopunny
# Saved 441-chatot
# Saved 435-skuntank
# Saved 440-happiny
# Saved 442-spiritomb
# Saved 437-bronzong
# Saved 446-munchlax
# Saved 438-bonsly
# Saved 439-mime-jr
# Saved 443-gible
# Saved 450-hippowdon
# Saved 452-drapion
# Saved 445-garchomp
# Saved 444-gabite
# Saved 455-carnivine
# Saved 432-purugly
# Saved 449-hippopotas
# Saved 448-lucario
# Saved 447-riolu
# Saved 461-weavile
# Saved 457-lumineon
# Saved 458-mantyke
# Saved 459-snover
# Saved 454-toxicroak
# Saved 466-electivire
# Saved 453-croagunk
# Saved 451-skorupi
# Saved 460-abomasnow
# Saved 462-magnezone
# Saved 463-lickilicky
# Saved 468-togekiss
# Saved 464-rhyperior
# Saved 456-finneon
# Saved 465-tangrowth
# Saved 475-gallade
# Saved 467-magmortar
# Saved 478-froslass
# Saved 474-porygon-z
# Saved 469-yanmega
# Saved 470-leafeon
# Saved 476-probopass
# Saved 471-glaceon
# Saved 472-gliscor
# Saved 479-rotom
# Saved 473-mamoswine
# Saved 482-azelf
# Saved 477-dusknoir
# Saved 486-regigigas
# Saved 481-mespritSaved 480-uxie
#
# Saved 489-phione
# Saved 483-dialga
# Saved 485-heatran
# Saved 484-palkia
# Saved 491-darkrai
# Saved 487-giratina-altered
# Saved 494-victini
# Saved 498-tepig
# Saved 493-arceus
# Saved 495-snivy
# Saved 488-cresselia
# Saved 490-manaphy
# Saved 501-oshawott
# Saved 499-pignite
# Saved 505-watchog
# Saved 492-shaymin-land
# Saved 504-patrat
# Saved 497-serperior
# Saved 507-herdier
# Saved 503-samurott
# Saved 510-liepard
# Saved 508-stoutland
# Saved 496-servine
# Saved 502-dewott
# Saved 509-purrloin
# Saved 500-emboar
# Saved 511-pansage
# Saved 506-lillipup
# Saved 517-munna
# Saved 514-simisear
# Saved 515-panpour
# Saved 521-unfezant
# Saved 518-musharna
# Saved 512-simisage
# Saved 513-pansear
# Saved 523-zebstrika
# Saved 525-boldore
# Saved 526-gigalith
# Saved 519-pidove
# Saved 522-blitzle
# Saved 529-drilbur
# Saved 524-roggenrola
# Saved 520-tranquill
# Saved 532-timburr
# Saved 527-woobat
# Saved 533-gurdurr
# Saved 537-seismitoad
# Saved 528-swoobat
# Saved 516-simipour
# Saved 530-excadrill
# Saved 538-throh
# Saved 539-sawk
# Saved 540-sewaddle
# Saved 534-conkeldurr
# Saved 544-whirlipede
# Saved 536-palpitoad
# Saved 535-tympole
# Saved 531-audino
# Saved 541-swadloon
# Saved 542-leavanny
# Saved 551-sandile
# Saved 543-venipede
# Saved 545-scolipedeSaved 554-darumaka
#
# Saved 555-darmanitan-standard
# Saved 550-basculin-red-striped
# Saved 547-whimsicott
# Saved 546-cottonee
# Saved 553-krookodile
# Saved 549-lilligant
# Saved 556-maractus
# Saved 558-crustle
# Saved 563-cofagrigus
# Saved 552-krokorok
# Saved 548-petilil
# Saved 559-scraggy
# Saved 557-dwebble
# Saved 560-scrafty
# Saved 567-archeops
# Saved 562-yamask
# Saved 561-sigilyph
# Saved 564-tirtouga
# Saved 565-carracosta
# Saved 570-zorua
# Saved 576-gothitelle
# Saved 566-archen
# Saved 572-minccino
# Saved 573-cinccino
# Saved 571-zoroark
# Saved 568-trubbish
# Saved 569-garbodor
# Saved 574-gothita
# Saved 581-swanna
# Saved 575-gothorita
# Saved 583-vanillish
# Saved 584-vanilluxe
# Saved 577-solosis
# Saved 578-duosion
# Saved 579-reuniclus
# Saved 580-ducklett
# Saved 589-escavalier
# Saved 586-sawsbuck
# Saved 591-amoonguss
# Saved 582-vanillite
# Saved 592-frillish
# Saved 585-deerling
# Saved 587-emolga
# Saved 588-karrablast
# Saved 590-foongus
# Saved 597-ferroseed
# Saved 595-joltik
# Saved 594-alomomola
# Saved 593-jellicent
# Saved 596-galvantula
# Saved 598-ferrothorn
# Saved 605-elgyem
# Saved 599-klink
# Saved 604-eelektross
# Saved 600-klang
# Saved 609-chandelure
# Saved 602-tynamo
# Saved 613-cubchoo
# Saved 614-beartic
# Saved 603-eelektrik
# Saved 617-accelgor
# Saved 606-beheeyem
# Saved 607-litwick
# Saved 608-lampent
# Saved 601-klinklang
# Saved 610-axew
# Saved 611-fraxure
# Saved 612-haxorus
# Saved 618-stunfisk
# Saved 624-pawniard
# Saved 626-bouffalant
# Saved 616-shelmet
# Saved 615-cryogonal
# Saved 621-druddigon
# Saved 630-mandibuzz
# Saved 619-mienfoo
# Saved 620-mienshao
# Saved 628-braviary
# Saved 631-heatmor
# Saved 622-golett
# Saved 623-golurk
# Saved 634-zweilous
# Saved 632-durant
# Saved 636-larvesta
# Saved 637-volcarona
# Saved 627-rufflet
# Saved 638-cobalion
# Saved 641-tornadus-incarnate
# Saved 629-vullaby
# Saved 643-reshiram
# Saved 639-terrakion
# Saved 633-deino
# Saved 625-bisharp
# Saved 642-thundurus-incarnate
# Saved 635-hydreigon
# Saved 647-keldeo-ordinary
# Saved 644-zekrom
# Saved 640-virizion
# Saved 653-fennekin
# Saved 652-chesnaught
# Saved 645-landorus-incarnate
# Saved 656-froakie
# Saved 646-kyurem
# Saved 655-delphox
# Saved 648-meloetta-aria
# Saved 649-genesect
# Saved 650-chespin
# Saved 654-braixen
# Saved 651-quilladin
# Saved 664-scatterbug
# Saved 662-fletchinder
# Saved 667-litleo
# Saved 657-frogadier
# Saved 658-greninja
# Saved 669-flabebe
# Saved 660-diggersby
# Saved 661-fletchling
# Saved 663-talonflame
# Saved 665-spewpa
# Saved 673-gogoat
# Saved 671-florges
# Saved 676-furfrou
# Saved 674-pancham
# Saved 668-pyroar
# Saved 675-pangoro
# Saved 679-honedge
# Saved 670-floette
# Saved 659-bunnelby
# Saved 681-aegislash-shield
# Saved 677-espurr
# Saved 678-meowstic-male
# Saved 684-swirlix
# Saved 666-vivillon
# Saved 685-slurpuff
# Saved 686-inkay
# Saved 689-barbaracle
# Saved 691-dragalge
# Saved 690-skrelp
# Saved 692-clauncher
# Saved 682-spritzee
# Saved 672-skiddo
# Saved 683-aromatisse
# Saved 687-malamar
# Saved 696-tyrunt
# Saved 699-aurorus
# Saved 688-binacle
# Saved 694-helioptile
# Saved 680-doublade
# Saved 695-heliolisk
# Saved 693-clawitzer
# Saved 703-carbink
# Saved 702-dedenne
# Saved 704-goomy
# Saved 705-sliggoo
# Saved 697-tyrantrum
# Saved 698-amaura
# Saved 708-phantump
# Saved 700-sylveon
# Saved 709-trevenant
# Saved 701-hawlucha
# Saved 706-goodra
# Saved 712-bergmite
# Saved 716-xerneas
# Saved 715-noivern
# Saved 714-noibat
# Saved 717-yveltal
# Saved 718-zygarde-50
# Saved 721-volcanion
# Saved 722-rowlet
# Saved 707-klefki
# Saved 710-pumpkaboo-average
# Saved 726-torracat
# Saved 728-popplio
# Saved 713-avalugg
# Saved 723-dartrix
# Saved 725-litten
# Saved 729-brionne
# Saved 711-gourgeist-average
# Saved 719-diancie
# Saved 734-yungoos
# Saved 720-hoopa
# Saved 736-grubbin
# Saved 724-decidueye
# Saved 727-incineroar
# Saved 737-charjabug
# Saved 735-gumshoos
# Saved 740-crabominable
# Saved 743-ribombee
# Saved 730-primarina
# Saved 731-pikipek
# Saved 732-trumbeak
# Saved 733-toucannon
# Saved 749-mudbray
# Saved 748-toxapex
# Saved 747-mareanie
# Saved 739-crabrawler
# Saved 741-oricorio-baile
# Saved 746-wishiwashi-solo
# Saved 750-mudsdale
# Saved 738-vikavolt
# Saved 744-rockruff
# Saved 756-shiinotic
# Saved 745-lycanroc-midday
# Saved 752-araquanid
# Saved 757-salandit
# Saved 759-stufful
# Saved 755-morelull
# Saved 753-fomantis
# Saved 760-bewear
# Saved 742-cutiefly
# Saved 762-steenee
# Saved 751-dewpider
# Saved 763-tsareena
# Saved 767-wimpod
# Saved 754-lurantis
# Saved 758-salazzle
# Saved 771-pyukumuku
# Saved 769-sandygast
# Saved 764-comfey
# Saved 766-passimian
# Saved 775-komala
# Saved 777-togedemaru
# Saved 765-oranguru
# Saved 768-golisopod
# Saved 770-palossand
# Saved 781-dhelmise
# Saved 761-bounsweet
# Saved 774-minior-red-meteor
# Saved 773-silvally
# Saved 772-type-null
# Saved 776-turtonator
# Saved 785-tapu-koko
# Saved 783-hakamo-o
# Saved 784-kommo-o
# Saved 778-mimikyu-disguised
# Saved 780-drampa
# Saved 792-lunala
# Saved 786-tapu-lele
# Saved 787-tapu-bulu
# Saved 788-tapu-fini
# Saved 789-cosmog
# Saved 795-pheromosa
# Saved 791-solgaleo
# Saved 797-celesteela
# Saved 782-jangmo-o
# Saved 790-cosmoem
# Saved 793-nihilego
# Saved 799-guzzlord
# Saved 794-buzzwole
# Saved 801-magearna
# Saved 800-necrozma
# Saved 805-stakataka
# Saved 803-poipole
# Saved 796-xurkitree
# Saved 807-zeraora
# Saved 808-meltan
# Saved 809-melmetal
# Saved 798-kartana
# Saved 810-grookey
# Saved 811-thwackey
# Saved 802-marshadow
# Saved 813-scorbunny
# Saved 804-naganadel
# Saved 812-rillaboom
# Saved 819-skwovet
# Saved 816-sobble
# Saved 817-drizzile
# Saved 818-inteleon
# Saved 825-dottler
# Saved 779-bruxish
# Saved 815-cinderace
# Saved 822-corvisquire
# Saved 814-raboot
# Saved 806-blacephalon
# Saved 828-thievul
# Saved 820-greedent
# Saved 831-wooloo
# Saved 821-rookidee
# Saved 833-chewtle
# Saved 823-corviknight
# Saved 830-eldegoss
# Saved 824-blipbug
# Saved 826-orbeetle
# Saved 827-nickit
# Saved 836-boltund
# Saved 829-gossifleur
# Saved 832-dubwool
# Saved 839-coalossal
# Saved 842-appletun
# Saved 843-silicobra
# Saved 840-applin
# Saved 835-yamper
# Saved 847-barraskewda
# Saved 834-drednaw
# Saved 841-flapple
# Saved 844-sandaconda
# Saved 838-carkol
# Saved 837-rolycoly
# Saved 849-toxtricity-amped
# Saved 846-arrokuda
# Saved 852-clobbopus
# Saved 855-polteageist
# Saved 854-sinistea
# Saved 850-sizzlipede
# Saved 859-impidimp
# Saved 845-cramorant
# Saved 861-grimmsnarl
# Saved 848-toxel
# Saved 851-centiskorch
# Saved 857-hattrem
# Saved 853-grapploct
# Saved 865-sirfetchd
# Saved 863-perrserker
# Saved 856-hatenna
# Saved 869-alcremie
# Saved 860-morgrem
# Saved 867-runerigus
# Saved 858-hatterene
# Saved 870-falinks
# Saved 862-obstagoon
# Saved 864-cursola
# Saved 873-frosmoth
# Saved 871-pincurchin
# Saved 877-morpeko-full-belly
# Saved 876-indeedee-male
# Saved 866-mr-rime
# Saved 868-milcery
# Saved 879-copperajah
# Saved 874-stonjourner
# Saved 875-eiscue-ice
# Saved 878-cufant
# Saved 886-drakloak
# Saved 881-arctozolt
# Saved 888-zacian
# Saved 882-dracovish
# Saved 883-arctovish
# Saved 872-snom
# Saved 885-dreepy
# Saved 884-duraludon
# Saved 890-eternatus
# Saved 894-regieleki
# Saved 889-zamazenta
# Saved 895-regidrago
# Saved 897-spectrier
# Saved 891-kubfu
# Saved 880-dracozolt
# Saved 887-dragapult
# Saved 898-calyrex
# Saved 901-ursaluna
# Saved 900-kleavor
# Saved 896-glastrier
# Saved 893-zarude
# Saved 892-urshifu-single-strike
# Saved 903-sneasler
# Saved 899-wyrdeer
# Saved 905-enamorus-incarnate
# Saved 902-basculegion-male
# Saved 911-skeledirge
# Saved 904-overqwil
# Saved 906-sprigatito
# Saved 907-floragato
# Saved 908-meowscarada
# Saved 914-quaquaval
# Saved 910-crocalor
# Saved 912-quaxly
# Saved 913-quaxwell
# Saved 915-lechonk
# Saved 921-pawmi
# Saved 917-tarountulaSaved 923-pawmot
#
# Saved 909-fuecoco
# Saved 916-oinkologne-male
# Saved 918-spidops
# Saved 919-nymble
# Saved 920-lokix
# Saved 922-pawmoSaved 926-fidough
#
# Saved 929-dolliv
# Saved 925-maushold-family-of-four
# Saved 924-tandemaus
# Saved 932-nacli
# Saved 934-garganacl
# Saved 927-dachsbun
# Saved 928-smoliv
# Saved 937-ceruledge
# Saved 930-arboliva
# Saved 931-squawkabilly-green-plumage
# Saved 936-armarouge
# Saved 933-naclstack
# Saved 944-shroodle
# Saved 945-grafaiai
# Saved 935-charcadet
# Saved 938-tadbulb
# Saved 940-wattrel
# Saved 939-bellibolt
# Saved 942-maschiff
# Saved 943-mabosstiff
# Saved 941-kilowattrel
# Saved 946-bramblin
# Saved 952-scovillain
# Saved 953-rellor
# Saved 947-brambleghast
# Saved 949-toedscruel
# Saved 950-klawf
# Saved 951-capsakid
# Saved 956-espathra
# Saved 948-toedscool
# Saved 959-tinkaton
# Saved 955-flittle
# Saved 960-wiglett
# Saved 954-rabsca
# Saved 957-tinkatink
# Saved 965-varoom
# Saved 958-tinkatuff
# Saved 962-bombirdier
# Saved 968-orthworm
# Saved 969-glimmet
# Saved 970-glimmora
# Saved 963-finizen
# Saved 967-cyclizar
# Saved 964-palafin-zero
# Saved 966-revavroom
# Saved 974-cetoddle
# Saved 961-wugtrio
# Saved 972-houndstone
# Saved 971-greavard
# Saved 980-clodsire
# Saved 975-cetitan
# Saved 981-farigiraf
# Saved 978-tatsugiri-curly
# Saved 976-veluza
# Saved 973-flamigo
# Saved 986-brute-bonnet
# Saved 983-kingambit
# Saved 985-scream-tail
# Saved 977-dondozo
# Saved 990-iron-treads
# Saved 979-annihilape
# Saved 984-great-tusk
# Saved 987-flutter-mane
# Saved 988-slither-wing
# Saved 989-sandy-shocks
# Saved 991-iron-bundle
# Saved 996-frigibax
# Saved 998-baxcalibur
# Saved 992-iron-hands
# Saved 995-iron-thorns
# Saved 993-iron-jugulis
# Saved 994-iron-moth
# Saved 982-dudunsparce-two-segment
# Saved 1000-gholdengo
# Saved 1001-wo-chien
# Saved 997-arctibax
# Saved 999-gimmighoul
# Saved 1008-miraidon
# Saved 1009-walking-wake
# Saved 1010-iron-leaves
# Saved 1003-ting-lu
# Saved 1011-dipplin
# Saved 1007-koraidon
# Saved 1004-chi-yu
# Saved 1005-roaring-moon
# Saved 1015-munkidori
# Saved 1014-okidogi
# Saved 1018-archaludon
# Saved 1012-poltchageist
# Saved 1013-sinistcha
# Saved 1019-hydrapple
# Saved 1016-fezandipiti
# Saved 1023-iron-crown
# Saved 1020-gouging-fire
# Saved 1025-pecharunt
# Saved 1021-raging-bolt
# Saved 1022-iron-boulder
# Saved 1002-chien-pao
# Saved 1017-ogerpon
# Failed to fetch/save shaymin-sky: Expecting value: line 1 column 1 (char 0)Failed to fetch/save deoxys-defense: Expecting value: line 1 column 1 (char 0)
#
# Saved 1006-iron-valiant
# Failed to fetch/save giratina-origin: Expecting value: line 1 column 1 (char 0)
# Saved 1024-terapagos
# Failed to fetch/save deoxys-speed: Expecting value: line 1 column 1 (char 0)
# Failed to fetch/save wormadam-sandy: Expecting value: line 1 column 1 (char 0)
# Failed to fetch/save rotom-frost: Expecting value: line 1 column 1 (char 0)
# Failed to fetch/save deoxys-attack: Expecting value: line 1 column 1 (char 0)
# Failed to fetch/save wormadam-trash: Expecting value: line 1 column 1 (char 0)
# Failed to fetch/save rotom-fan: Expecting value: line 1 column 1 (char 0)
# Failed to fetch/save rotom-mow: Expecting value: line 1 column 1 (char 0)
# Failed to fetch/save rotom-heat: Expecting value: line 1 column 1 (char 0)
# Failed to fetch/save castform-rainy: Expecting value: line 1 column 1 (char 0)
# Failed to fetch/save castform-snowy: Expecting value: line 1 column 1 (char 0)
# Failed to fetch/save tornadus-therian: Expecting value: line 1 column 1 (char 0)
# Failed to fetch/save landorus-therian: Expecting value: line 1 column 1 (char 0)
# Failed to fetch/save kyurem-white: Expecting value: line 1 column 1 (char 0)
# Failed to fetch/save thundurus-therian: Expecting value: line 1 column 1 (char 0)
# Failed to fetch/save castform-sunny: Expecting value: line 1 column 1 (char 0)
# Failed to fetch/save meloetta-pirouette: Expecting value: line 1 column 1 (char 0)
# Failed to fetch/save kyurem-black: Expecting value: line 1 column 1 (char 0)
# Failed to fetch/save pumpkaboo-super: Expecting value: line 1 column 1 (char 0)
# Failed to fetch/save gourgeist-small: Expecting value: line 1 column 1 (char 0)
# Failed to fetch/save pumpkaboo-small: Expecting value: line 1 column 1 (char 0)
# Failed to fetch/save meowstic-female: Expecting value: line 1 column 1 (char 0)
# Failed to fetch/save aegislash-blade: Expecting value: line 1 column 1 (char 0)
# Failed to fetch/save gourgeist-super: Expecting value: line 1 column 1 (char 0)
# Failed to fetch/save venusaur-mega: Expecting value: line 1 column 1 (char 0)
# Failed to fetch/save charizard-mega-x: Expecting value: line 1 column 1 (char 0)
# Failed to fetch/save keldeo-resolute: Expecting value: line 1 column 1 (char 0)
# Failed to fetch/save pumpkaboo-large: Expecting value: line 1 column 1 (char 0)
# Failed to fetch/save rotom-wash: Expecting value: line 1 column 1 (char 0)
# Failed to fetch/save gourgeist-large: Expecting value: line 1 column 1 (char 0)
# Failed to fetch/save gengar-mega: Expecting value: line 1 column 1 (char 0)
# Failed to fetch/save charizard-mega-y: Expecting value: line 1 column 1 (char 0)
# Failed to fetch/save kangaskhan-mega: Expecting value: line 1 column 1 (char 0)
# Failed to fetch/save alakazam-mega: Expecting value: line 1 column 1 (char 0)
# Failed to fetch/save basculin-blue-striped: Expecting value: line 1 column 1 (char 0)
# Failed to fetch/save darmanitan-zen: Expecting value: line 1 column 1 (char 0)
# Failed to fetch/save blastoise-mega: Expecting value: line 1 column 1 (char 0)
# Failed to fetch/save aerodactyl-mega: Expecting value: line 1 column 1 (char 0)
# Failed to fetch/save ampharos-mega: Expecting value: line 1 column 1 (char 0)
# Failed to fetch/save mewtwo-mega-y: Expecting value: line 1 column 1 (char 0)
# Failed to fetch/save gyarados-mega: Expecting value: line 1 column 1 (char 0)
# Failed to fetch/save heracross-mega: Expecting value: line 1 column 1 (char 0)
# Failed to fetch/save houndoom-mega: Expecting value: line 1 column 1 (char 0)
# Failed to fetch/save tyranitar-mega: Expecting value: line 1 column 1 (char 0)
# Failed to fetch/save mewtwo-mega-x: Expecting value: line 1 column 1 (char 0)
# Failed to fetch/save mawile-mega: Expecting value: line 1 column 1 (char 0)
# Failed to fetch/save scizor-mega: Expecting value: line 1 column 1 (char 0)
# Failed to fetch/save medicham-mega: Expecting value: line 1 column 1 (char 0)
# Failed to fetch/save aggron-mega: Expecting value: line 1 column 1 (char 0)
# Failed to fetch/save manectric-mega: Expecting value: line 1 column 1 (char 0)
# Failed to fetch/save blaziken-mega: Expecting value: line 1 column 1 (char 0)
# Failed to fetch/save lucario-mega: Expecting value: line 1 column 1 (char 0)
# Failed to fetch/save gardevoir-mega: Expecting value: line 1 column 1 (char 0)
# Failed to fetch/save pinsir-mega: Expecting value: line 1 column 1 (char 0)
# Failed to fetch/save floette-eternal: Expecting value: line 1 column 1 (char 0)
# Failed to fetch/save garchomp-mega: Expecting value: line 1 column 1 (char 0)
# Failed to fetch/save abomasnow-mega: Expecting value: line 1 column 1 (char 0)
# Failed to fetch/save swampert-mega: Expecting value: line 1 column 1 (char 0)
# Failed to fetch/save latias-mega: Expecting value: line 1 column 1 (char 0)
# Failed to fetch/save sceptile-mega: Expecting value: line 1 column 1 (char 0)
# Failed to fetch/save sableye-mega: Expecting value: line 1 column 1 (char 0)
# Failed to fetch/save slowbro-mega: Expecting value: line 1 column 1 (char 0)
# Failed to fetch/save sharpedo-mega: Expecting value: line 1 column 1 (char 0)
# Failed to fetch/save audino-mega: Expecting value: line 1 column 1 (char 0)
# Failed to fetch/save banette-mega: Expecting value: line 1 column 1 (char 0)
# Failed to fetch/save metagross-mega: Expecting value: line 1 column 1 (char 0)
# Failed to fetch/save pidgeot-mega: Expecting value: line 1 column 1 (char 0)
# Failed to fetch/save absol-mega: Expecting value: line 1 column 1 (char 0)
# Failed to fetch/save diancie-mega: Expecting value: line 1 column 1 (char 0)
# Failed to fetch/save steelix-mega: Expecting value: line 1 column 1 (char 0)
# Failed to fetch/save gallade-mega: Expecting value: line 1 column 1 (char 0)
# Failed to fetch/save kyogre-primal: Expecting value: line 1 column 1 (char 0)
# Failed to fetch/save glalie-mega: Expecting value: line 1 column 1 (char 0)
# Failed to fetch/save rayquaza-mega: Expecting value: line 1 column 1 (char 0)
# Failed to fetch/save latios-mega: Expecting value: line 1 column 1 (char 0)
# Failed to fetch/save groudon-primal: Expecting value: line 1 column 1 (char 0)
# Failed to fetch/save pikachu-rock-star: Expecting value: line 1 column 1 (char 0)
# Failed to fetch/save pikachu-libre: Expecting value: line 1 column 1 (char 0)
# Failed to fetch/save altaria-mega: Expecting value: line 1 column 1 (char 0)
# Failed to fetch/save pikachu-pop-star: Expecting value: line 1 column 1 (char 0)
# Failed to fetch/save pikachu-belle: Expecting value: line 1 column 1 (char 0)
# Failed to fetch/save pikachu-cosplay: Expecting value: line 1 column 1 (char 0)
# Failed to fetch/save hoopa-unbound: Expecting value: line 1 column 1 (char 0)
# Failed to fetch/save camerupt-mega: Expecting value: line 1 column 1 (char 0)
# Failed to fetch/save salamence-mega: Expecting value: line 1 column 1 (char 0)
# Failed to fetch/save rattata-alola: Expecting value: line 1 column 1 (char 0)
# Failed to fetch/save lopunny-mega: Expecting value: line 1 column 1 (char 0)
# Failed to fetch/save pikachu-phd: Expecting value: line 1 column 1 (char 0)
# Failed to fetch/save raticate-alola: Expecting value: line 1 column 1 (char 0)
# Failed to fetch/save pikachu-original-cap: Expecting value: line 1 column 1 (char 0)
# Failed to fetch/save raichu-alola: Expecting value: line 1 column 1 (char 0)
# Failed to fetch/save pikachu-kalos-cap: Expecting value: line 1 column 1 (char 0)
# Failed to fetch/save pikachu-sinnoh-cap: Expecting value: line 1 column 1 (char 0)
# Failed to fetch/save pikachu-alola-cap: Expecting value: line 1 column 1 (char 0)
# Failed to fetch/save pikachu-unova-cap: Expecting value: line 1 column 1 (char 0)
# Failed to fetch/save beedrill-mega: Expecting value: line 1 column 1 (char 0)
# Failed to fetch/save ninetales-alola: Expecting value: line 1 column 1 (char 0)Failed to fetch/save vulpix-alola: Expecting value: line 1 column 1 (char 0)
#
# Failed to fetch/save diglett-alola: Expecting value: line 1 column 1 (char 0)
# Failed to fetch/save meowth-alola: Expecting value: line 1 column 1 (char 0)
# Failed to fetch/save dugtrio-alola: Expecting value: line 1 column 1 (char 0)
# Failed to fetch/save graveler-alola: Expecting value: line 1 column 1 (char 0)
# Failed to fetch/save geodude-alola: Expecting value: line 1 column 1 (char 0)
# Failed to fetch/save raticate-totem-alola: Expecting value: line 1 column 1 (char 0)
# Failed to fetch/save muk-alola: Expecting value: line 1 column 1 (char 0)
# Failed to fetch/save marowak-alola: Expecting value: line 1 column 1 (char 0)
# Failed to fetch/save golem-alola: Expecting value: line 1 column 1 (char 0)
# Failed to fetch/save greninja-battle-bond: Expecting value: line 1 column 1 (char 0)
# Failed to fetch/save sandslash-alola: Expecting value: line 1 column 1 (char 0)
# Failed to fetch/save greninja-ash: Expecting value: line 1 column 1 (char 0)
# Failed to fetch/save grimer-alola: Expecting value: line 1 column 1 (char 0)
# Failed to fetch/save pikachu-hoenn-cap: Expecting value: line 1 column 1 (char 0)
# Failed to fetch/save sandshrew-alola: Expecting value: line 1 column 1 (char 0)
# Failed to fetch/save gumshoos-totem: Expecting value: line 1 column 1 (char 0)
# Failed to fetch/save zygarde-50-power-construct: Expecting value: line 1 column 1 (char 0)
# Failed to fetch/save vikavolt-totem: Expecting value: line 1 column 1 (char 0)
# Failed to fetch/save zygarde-10-power-construct: Expecting value: line 1 column 1 (char 0)
# Failed to fetch/save oricorio-pau: Expecting value: line 1 column 1 (char 0)
# Failed to fetch/save oricorio-pom-pom: Expecting value: line 1 column 1 (char 0)
# Failed to fetch/save oricorio-sensu: Expecting value: line 1 column 1 (char 0)
# Failed to fetch/save lycanroc-midnight: Expecting value: line 1 column 1 (char 0)
# Failed to fetch/save wishiwashi-school: Expecting value: line 1 column 1 (char 0)
# Failed to fetch/save lurantis-totem: Expecting value: line 1 column 1 (char 0)
# Failed to fetch/save minior-blue-meteor: Expecting value: line 1 column 1 (char 0)
# Failed to fetch/save salazzle-totem: Expecting value: line 1 column 1 (char 0)
# Failed to fetch/save minior-orange-meteor: Expecting value: line 1 column 1 (char 0)
# Failed to fetch/save minior-violet-meteor: Expecting value: line 1 column 1 (char 0)
# Failed to fetch/save minior-yellow-meteor: Expecting value: line 1 column 1 (char 0)
# Failed to fetch/save persian-alola: Expecting value: line 1 column 1 (char 0)
# Failed to fetch/save minior-green-meteor: Expecting value: line 1 column 1 (char 0)
# Failed to fetch/save minior-red: Expecting value: line 1 column 1 (char 0)
# Failed to fetch/save minior-yellow: Expecting value: line 1 column 1 (char 0)
# Failed to fetch/save zygarde-complete: Expecting value: line 1 column 1 (char 0)
# Failed to fetch/save exeggutor-alola: Expecting value: line 1 column 1 (char 0)
# Failed to fetch/save minior-orange: Expecting value: line 1 column 1 (char 0)
# Failed to fetch/save minior-indigo: Expecting value: line 1 column 1 (char 0)
# Failed to fetch/save minior-green: Expecting value: line 1 column 1 (char 0)
# Failed to fetch/save kommo-o-totem: Expecting value: line 1 column 1 (char 0)
# Failed to fetch/save mimikyu-totem-disguised: Expecting value: line 1 column 1 (char 0)
# Failed to fetch/save mimikyu-totem-busted: Expecting value: line 1 column 1 (char 0)
# Failed to fetch/save pikachu-partner-cap: Expecting value: line 1 column 1 (char 0)
# Failed to fetch/save magearna-original: Expecting value: line 1 column 1 (char 0)
# Failed to fetch/save marowak-totem: Expecting value: line 1 column 1 (char 0)
# Failed to fetch/save rockruff-own-tempo: Expecting value: line 1 column 1 (char 0)
# Failed to fetch/save togedemaru-totem: Expecting value: line 1 column 1 (char 0)
# Failed to fetch/save ribombee-totem: Expecting value: line 1 column 1 (char 0)
# Failed to fetch/save araquanid-totem: Expecting value: line 1 column 1 (char 0)
# Failed to fetch/save minior-indigo-meteor: Expecting value: line 1 column 1 (char 0)
# Failed to fetch/save minior-violet: Expecting value: line 1 column 1 (char 0)
# Failed to fetch/save eevee-starter: Expecting value: line 1 column 1 (char 0)
# Failed to fetch/save necrozma-ultra: Expecting value: line 1 column 1 (char 0)
# Failed to fetch/save minior-blue: Expecting value: line 1 column 1 (char 0)
# Failed to fetch/save necrozma-dusk: Expecting value: line 1 column 1 (char 0)
# Failed to fetch/save mimikyu-busted: Expecting value: line 1 column 1 (char 0)
# Failed to fetch/save rapidash-galar: Expecting value: line 1 column 1 (char 0)
# Failed to fetch/save pikachu-world-cap: Expecting value: line 1 column 1 (char 0)
# Failed to fetch/save necrozma-dawn: Expecting value: line 1 column 1 (char 0)
# Failed to fetch/save ponyta-galar: Expecting value: line 1 column 1 (char 0)
# Failed to fetch/save meowth-galar: Expecting value: line 1 column 1 (char 0)
# Failed to fetch/save weezing-galar: Expecting value: line 1 column 1 (char 0)
# Failed to fetch/save pikachu-starter: Expecting value: line 1 column 1 (char 0)
# Failed to fetch/save farfetchd-galar: Expecting value: line 1 column 1 (char 0)
# Failed to fetch/save mr-mime-galar: Expecting value: line 1 column 1 (char 0)
# Failed to fetch/save slowpoke-galar: Expecting value: line 1 column 1 (char 0)
# Failed to fetch/save slowbro-galar: Expecting value: line 1 column 1 (char 0)
# Failed to fetch/save moltres-galar: Expecting value: line 1 column 1 (char 0)
# Failed to fetch/save slowking-galar: Expecting value: line 1 column 1 (char 0)
# Failed to fetch/save corsola-galar: Expecting value: line 1 column 1 (char 0)
# Failed to fetch/save zigzagoon-galar: Expecting value: line 1 column 1 (char 0)
# Failed to fetch/save lycanroc-dusk: Expecting value: line 1 column 1 (char 0)
# Failed to fetch/save articuno-galar: Expecting value: line 1 column 1 (char 0)
# Failed to fetch/save zapdos-galar: Expecting value: line 1 column 1 (char 0)
# Failed to fetch/save zygarde-10: Expecting value: line 1 column 1 (char 0)
# Failed to fetch/save cramorant-gulping: Expecting value: line 1 column 1 (char 0)
# Failed to fetch/save linoone-galar: Expecting value: line 1 column 1 (char 0)
# Failed to fetch/save darmanitan-galar-standard: Expecting value: line 1 column 1 (char 0)
# Failed to fetch/save stunfisk-galar: Expecting value: line 1 column 1 (char 0)
# Failed to fetch/save darmanitan-galar-zen: Expecting value: line 1 column 1 (char 0)
# Failed to fetch/save eiscue-noice: Expecting value: line 1 column 1 (char 0)
# Failed to fetch/save yamask-galar: Expecting value: line 1 column 1 (char 0)
# Failed to fetch/save cramorant-gorging: Expecting value: line 1 column 1 (char 0)
# Failed to fetch/save toxtricity-low-key: Expecting value: line 1 column 1 (char 0)
# Failed to fetch/save darumaka-galar: Expecting value: line 1 column 1 (char 0)
# Failed to fetch/save morpeko-hangry: Expecting value: line 1 column 1 (char 0)
# Failed to fetch/save indeedee-female: Expecting value: line 1 column 1 (char 0)
# Failed to fetch/save zacian-crowned: Expecting value: line 1 column 1 (char 0)
# Failed to fetch/save calyrex-ice: Expecting value: line 1 column 1 (char 0)
# Failed to fetch/save eternatus-eternamax: Expecting value: line 1 column 1 (char 0)
# Failed to fetch/save urshifu-rapid-strike: Expecting value: line 1 column 1 (char 0)
# Failed to fetch/save zamazenta-crowned: Expecting value: line 1 column 1 (char 0)
# Failed to fetch/save meowth-gmax: Expecting value: line 1 column 1 (char 0)
# Failed to fetch/save venusaur-gmax: Expecting value: line 1 column 1 (char 0)
# Failed to fetch/save charizard-gmax: Expecting value: line 1 column 1 (char 0)
# Failed to fetch/save blastoise-gmax: Expecting value: line 1 column 1 (char 0)
# Failed to fetch/save gengar-gmax: Expecting value: line 1 column 1 (char 0)
# Failed to fetch/save pikachu-gmax: Expecting value: line 1 column 1 (char 0)
# Failed to fetch/save zarude-dada: Expecting value: line 1 column 1 (char 0)
# Failed to fetch/save eevee-gmax: Expecting value: line 1 column 1 (char 0)
# Failed to fetch/save machamp-gmax: Expecting value: line 1 column 1 (char 0)
# Failed to fetch/save kingler-gmax: Expecting value: line 1 column 1 (char 0)
# Failed to fetch/save lapras-gmax: Expecting value: line 1 column 1 (char 0)
# Failed to fetch/save butterfree-gmax: Expecting value: line 1 column 1 (char 0)
# Failed to fetch/save inteleon-gmax: Expecting value: line 1 column 1 (char 0)
# Failed to fetch/save garbodor-gmax: Expecting value: line 1 column 1 (char 0)
# Failed to fetch/save rillaboom-gmax: Expecting value: line 1 column 1 (char 0)
# Failed to fetch/save corviknight-gmax: Expecting value: line 1 column 1 (char 0)
# Failed to fetch/save drednaw-gmax: Expecting value: line 1 column 1 (char 0)
# Failed to fetch/save flapple-gmax: Expecting value: line 1 column 1 (char 0)
# Failed to fetch/save cinderace-gmax: Expecting value: line 1 column 1 (char 0)
# Failed to fetch/save calyrex-shadow: Expecting value: line 1 column 1 (char 0)
# Failed to fetch/save orbeetle-gmax: Expecting value: line 1 column 1 (char 0)
# Failed to fetch/save centiskorch-gmax: Expecting value: line 1 column 1 (char 0)
# Failed to fetch/save coalossal-gmax: Expecting value: line 1 column 1 (char 0)
# Failed to fetch/save hatterene-gmax: Expecting value: line 1 column 1 (char 0)
# Failed to fetch/save grimmsnarl-gmax: Expecting value: line 1 column 1 (char 0)
# Failed to fetch/save sandaconda-gmax: Expecting value: line 1 column 1 (char 0)
# Failed to fetch/save toxtricity-amped-gmax: Expecting value: line 1 column 1 (char 0)
# Failed to fetch/save copperajah-gmax: Expecting value: line 1 column 1 (char 0)
# Failed to fetch/save urshifu-single-strike-gmax: Expecting value: line 1 column 1 (char 0)
# Failed to fetch/save toxtricity-low-key-gmax: Expecting value: line 1 column 1 (char 0)
# Failed to fetch/save alcremie-gmax: Expecting value: line 1 column 1 (char 0)
# Failed to fetch/save growlithe-hisui: Expecting value: line 1 column 1 (char 0)
# Failed to fetch/save duraludon-gmax: Expecting value: line 1 column 1 (char 0)
# Failed to fetch/save arcanine-hisui: Expecting value: line 1 column 1 (char 0)
# Failed to fetch/save appletun-gmax: Expecting value: line 1 column 1 (char 0)
# Failed to fetch/save urshifu-rapid-strike-gmax: Expecting value: line 1 column 1 (char 0)
# Failed to fetch/save typhlosion-hisui: Expecting value: line 1 column 1 (char 0)
# Failed to fetch/save electrode-hisui: Expecting value: line 1 column 1 (char 0)Failed to fetch/save zorua-hisui: Expecting value: line 1 column 1 (char 0)
#
# Failed to fetch/save melmetal-gmax: Expecting value: line 1 column 1 (char 0)
# Failed to fetch/save snorlax-gmax: Expecting value: line 1 column 1 (char 0)
# Failed to fetch/save zoroark-hisui: Expecting value: line 1 column 1 (char 0)
# Failed to fetch/save samurott-hisui: Expecting value: line 1 column 1 (char 0)
# Failed to fetch/save sliggoo-hisui: Expecting value: line 1 column 1 (char 0)
# Failed to fetch/save avalugg-hisui: Expecting value: line 1 column 1 (char 0)
# Failed to fetch/save lilligant-hisui: Expecting value: line 1 column 1 (char 0)
# Failed to fetch/save qwilfish-hisui: Expecting value: line 1 column 1 (char 0)
# Failed to fetch/save braviary-hisui: Expecting value: line 1 column 1 (char 0)
# Failed to fetch/save basculegion-female: Expecting value: line 1 column 1 (char 0)
# Failed to fetch/save decidueye-hisui: Expecting value: line 1 column 1 (char 0)
# Failed to fetch/save enamorus-therian: Expecting value: line 1 column 1 (char 0)
# Failed to fetch/save dialga-origin: Expecting value: line 1 column 1 (char 0)
# Failed to fetch/save palkia-origin: Expecting value: line 1 column 1 (char 0)Failed to fetch/save tauros-paldea-combat-breed: Expecting value: line 1 column 1 (char 0)
#
# Failed to fetch/save tauros-paldea-blaze-breed: Expecting value: line 1 column 1 (char 0)
# Failed to fetch/save basculin-white-striped: Expecting value: line 1 column 1 (char 0)
# Failed to fetch/save tauros-paldea-aqua-breed: Expecting value: line 1 column 1 (char 0)
# Failed to fetch/save oinkologne-female: Expecting value: line 1 column 1 (char 0)
# Failed to fetch/save wooper-paldea: Expecting value: line 1 column 1 (char 0)
# Failed to fetch/save dudunsparce-three-segment: Expecting value: line 1 column 1 (char 0)
# Failed to fetch/save sneasel-hisui: Expecting value: line 1 column 1 (char 0)
# Failed to fetch/save tatsugiri-droopy: Expecting value: line 1 column 1 (char 0)
# Failed to fetch/save voltorb-hisui: Expecting value: line 1 column 1 (char 0)
# Failed to fetch/save squawkabilly-yellow-plumage: Expecting value: line 1 column 1 (char 0)
# Failed to fetch/save tatsugiri-stretchy: Expecting value: line 1 column 1 (char 0)
# Failed to fetch/save squawkabilly-white-plumage: Expecting value: line 1 column 1 (char 0)
# Failed to fetch/save koraidon-limited-build: Expecting value: line 1 column 1 (char 0)
# Failed to fetch/save koraidon-swimming-build: Expecting value: line 1 column 1 (char 0)
# Failed to fetch/save goodra-hisui: Expecting value: line 1 column 1 (char 0)
# Failed to fetch/save squawkabilly-blue-plumage: Expecting value: line 1 column 1 (char 0)
# Failed to fetch/save maushold-family-of-three: Expecting value: line 1 column 1 (char 0)
# Failed to fetch/save koraidon-sprinting-build: Expecting value: line 1 column 1 (char 0)
# Failed to fetch/save miraidon-glide-mode: Expecting value: line 1 column 1 (char 0)
# Failed to fetch/save ursaluna-bloodmoon: Expecting value: line 1 column 1 (char 0)
# Failed to fetch/save koraidon-gliding-build: Expecting value: line 1 column 1 (char 0)
# Failed to fetch/save palafin-hero: Expecting value: line 1 column 1 (char 0)
# Failed to fetch/save miraidon-aquatic-mode: Expecting value: line 1 column 1 (char 0)
# Failed to fetch/save terapagos-terastal: Expecting value: line 1 column 1 (char 0)
# Failed to fetch/save ogerpon-wellspring-mask: Expecting value: line 1 column 1 (char 0)
# Failed to fetch/save miraidon-low-power-mode: Expecting value: line 1 column 1 (char 0)
# Failed to fetch/save miraidon-drive-mode: Expecting value: line 1 column 1 (char 0)
# Failed to fetch/save terapagos-stellar: Expecting value: line 1 column 1 (char 0)
# Failed to fetch/save ogerpon-cornerstone-mask: Expecting value: line 1 column 1 (char 0)
# Failed to fetch/save ogerpon-hearthflame-mask: Expecting value: line 1 column 1 (char 0)
# Failed to fetch/save gimmighoul-roaming: Expecting value: line 1 column 1 (char 0)
# All data fetched and saved!

# %% [markdown]
# # Serialize all data from JSONs

# %%
from dataclasses import dataclass
from pathlib import Path
from concurrent.futures import ThreadPoolExecutor
from typing import Optional, List
import json

# Constants
POKEMON_DIR = Path("pokemons")


# Define the Pokemon dataclass.
@dataclass
class Pokemon:
    id: int
    name: str
    type1: str
    type2: Optional[str]
    height: int
    weight: int
    color: str
    gen: int
    is_legendary: bool

def serialize_pokemon(pokemon_id: int) -> Pokemon:
    """
    Given a Pokémon ID, find its corresponding JSON files and return a serialized Pokemon instance.
    It is assumed that for each pokemon_id there are two files in the 'pokemons' directory:
      - The main pokemon data (filename containing '{id}-*.json' but not '-species')
      - The species data (filename containing '{id}-species.json')
    """
    
    # Find files matching the pokemon_id (both normal and species file)
    files = list(POKEMON_DIR.glob(f"{pokemon_id}-*.json"))
    print(f"Serializing files: {files}")
    
    # Identify the main pokemon file and the species file.
    pokemon_file = next((f for f in files if "-species" not in f.name), None)
    species_file = next((f for f in files if "-species" in f.name), None)
    
    if not pokemon_file or not species_file:
        raise FileNotFoundError(f"Required files for Pokemon id {pokemon_id} not found.")
    
    # Load data from the JSON files.
    with pokemon_file.open("r") as p_file, species_file.open("r") as s_file:
        pokemon_data = json.load(p_file)
        species_data = json.load(s_file)
    
    # Extract generation number from the URL.
    gen_url = species_data.get('generation', {}).get('url', '')
    generation = int(gen_url.rstrip('/').split("/")[-1]) if gen_url else 0
    
    # Determine the second type if available.
    type2_value = (
        pokemon_data['types'][1]['type']['name']
        if len(pokemon_data['types']) > 1
        else None
    )
    
    return Pokemon(
        id=pokemon_id,
        name=pokemon_data['name'],
        type1=pokemon_data['types'][0]['type']['name'],
        type2=type2_value,
        height=pokemon_data['height'],
        weight=pokemon_data['weight'],
        color=species_data['color']['name'],
        gen=generation,
        is_legendary=species_data['is_legendary']
    )

# Extract unique Pokémon IDs from all JSON file names.
pokemon_ids = {
    int(f.name.split("-")[0])
    for f in POKEMON_DIR.glob("*.json")
    if f.name[0].isdigit()
}

if not pokemon_ids:
    raise RuntimeError("No pokemon files found in the 'pokemons' directory.")


# Use ThreadPoolExecutor to serialize all Pokémon concurrently.
with ThreadPoolExecutor(max_workers=50) as executor:
    # Create tasks for each pokemon_id in the range 0 to max_pokemon_id (inclusive)
    futures = [executor.submit(serialize_pokemon, i)
               for i in range(min(pokemon_ids), max(pokemon_ids) + 1)]
    
    # Collect results. Note: the order here will correspond to the range order.
    results: List[Pokemon] = [future.result() for future in futures]

# 'results' now contains the list of serialized Pokemon objects.
print(f"Serialized {len(results)} Pokémon.")
# Out:
# Serializing files: [PosixPath('pokemons/2-ivysaur-species.json'), PosixPath('pokemons/2-ivysaur.json')]
# Serializing files: [PosixPath('pokemons/4-charmander-species.json'), PosixPath('pokemons/4-charmander.json')]
# Serializing files: [PosixPath('pokemons/32-nidoran-m-species.json'), PosixPath('pokemons/32-nidoran-m.json')]
# Serializing files: [PosixPath('pokemons/27-sandshrew-species.json'), PosixPath('pokemons/27-sandshrew.json')]
# Serializing files: [PosixPath('pokemons/30-nidorina.json'), PosixPath('pokemons/30-nidorina-species.json')]
# Serializing files: [PosixPath('pokemons/1-bulbasaur.json'), PosixPath('pokemons/1-bulbasaur-species.json')]
# Serializing files: [PosixPath('pokemons/3-venusaur.json'), PosixPath('pokemons/3-venusaur-species.json')]
# Serializing files: [PosixPath('pokemons/12-butterfree-species.json'), PosixPath('pokemons/12-butterfree.json')]
# Serializing files: [PosixPath('pokemons/21-spearow.json'), PosixPath('pokemons/21-spearow-species.json')]
# Serializing files: [PosixPath('pokemons/23-ekans.json'), PosixPath('pokemons/23-ekans-species.json')]
# Serializing files: [PosixPath('pokemons/16-pidgey-species.json'), PosixPath('pokemons/16-pidgey.json')]
# Serializing files: [PosixPath('pokemons/28-sandslash.json'), PosixPath('pokemons/28-sandslash-species.json')]
# Serializing files: [PosixPath('pokemons/8-wartortle-species.json'), PosixPath('pokemons/8-wartortle.json')]
# Serializing files: [PosixPath('pokemons/36-clefable-species.json'), PosixPath('pokemons/36-clefable.json')]
# Serializing files: [PosixPath('pokemons/19-rattata.json'), PosixPath('pokemons/19-rattata-species.json')]
# Serializing files: [PosixPath('pokemons/7-squirtle.json'), PosixPath('pokemons/7-squirtle-species.json')]
# Serializing files: [PosixPath('pokemons/9-blastoise-species.json'), PosixPath('pokemons/9-blastoise.json')]
# Serializing files: [PosixPath('pokemons/26-raichu-species.json'), PosixPath('pokemons/26-raichu.json')]
# Serializing files: [PosixPath('pokemons/13-weedle-species.json'), PosixPath('pokemons/13-weedle.json')]
# Serializing files: [PosixPath('pokemons/29-nidoran-f-species.json'), PosixPath('pokemons/29-nidoran-f.json')]
# Serializing files: [PosixPath('pokemons/6-charizard-species.json'), PosixPath('pokemons/6-charizard.json')]
# Serializing files: [PosixPath('pokemons/20-raticate-species.json'), PosixPath('pokemons/20-raticate.json')]
# Serializing files: [PosixPath('pokemons/33-nidorino-species.json'), PosixPath('pokemons/33-nidorino.json')]
# Serializing files: [PosixPath('pokemons/40-wigglytuff-species.json'), PosixPath('pokemons/40-wigglytuff.json')]
# Serializing files: [PosixPath('pokemons/39-jigglypuff.json'), PosixPath('pokemons/39-jigglypuff-species.json')]
# Serializing files: [PosixPath('pokemons/44-gloom.json'), PosixPath('pokemons/44-gloom-species.json')]
# Serializing files: [PosixPath('pokemons/22-fearow-species.json'), PosixPath('pokemons/22-fearow.json')]
# Serializing files: [PosixPath('pokemons/34-nidoking-species.json'), PosixPath('pokemons/34-nidoking.json')]
# Serializing files: [PosixPath('pokemons/38-ninetales.json'), PosixPath('pokemons/38-ninetales-species.json')]
# Serializing files: [PosixPath('pokemons/47-parasect.json'), PosixPath('pokemons/47-parasect-species.json')]
# Serializing files: [PosixPath('pokemons/49-venomoth-species.json'), PosixPath('pokemons/49-venomoth.json')]
# Serializing files: [PosixPath('pokemons/31-nidoqueen-species.json'), PosixPath('pokemons/31-nidoqueen.json')]
# Serializing files: [PosixPath('pokemons/35-clefairy.json'), PosixPath('pokemons/35-clefairy-species.json')]
# Serializing files: [PosixPath('pokemons/48-venonat-species.json'), PosixPath('pokemons/48-venonat.json')]
# Serializing files: [PosixPath('pokemons/50-diglett.json'), PosixPath('pokemons/50-diglett-species.json')]
# Serializing files: [PosixPath('pokemons/37-vulpix-species.json'), PosixPath('pokemons/37-vulpix.json')]
# Serializing files: [PosixPath('pokemons/24-arbok-species.json'), PosixPath('pokemons/24-arbok.json')]
# Serializing files: [PosixPath('pokemons/42-golbat-species.json'), PosixPath('pokemons/42-golbat.json')]
# Serializing files: [PosixPath('pokemons/10-caterpie-species.json'), PosixPath('pokemons/10-caterpie.json')]
# Serializing files: [PosixPath('pokemons/15-beedrill-species.json'), PosixPath('pokemons/15-beedrill.json')]
# Serializing files: [PosixPath('pokemons/43-oddish-species.json'), PosixPath('pokemons/43-oddish.json')]
# Serializing files: [PosixPath('pokemons/17-pidgeotto.json'), PosixPath('pokemons/17-pidgeotto-species.json')]
# Serializing files: [PosixPath('pokemons/18-pidgeot-species.json'), PosixPath('pokemons/18-pidgeot.json')]
# Serializing files: [PosixPath('pokemons/45-vileplume.json'), PosixPath('pokemons/45-vileplume-species.json')]
# Serializing files: [PosixPath('pokemons/11-metapod-species.json'), PosixPath('pokemons/11-metapod.json')]
# Serializing files: [PosixPath('pokemons/14-kakuna-species.json'), PosixPath('pokemons/14-kakuna.json')]
# Serializing files: [PosixPath('pokemons/25-pikachu-species.json'), PosixPath('pokemons/25-pikachu.json')]
# Serializing files: [PosixPath('pokemons/5-charmeleon.json'), PosixPath('pokemons/5-charmeleon-species.json')]
# Serializing files: [PosixPath('pokemons/46-paras-species.json'), PosixPath('pokemons/46-paras.json')]
# Serializing files: [PosixPath('pokemons/41-zubat-species.json'), PosixPath('pokemons/41-zubat.json')]
# Serializing files: [PosixPath('pokemons/86-seel.json'), PosixPath('pokemons/86-seel-species.json')]
# Serializing files: [PosixPath('pokemons/81-magnemite-species.json'), PosixPath('pokemons/81-magnemite.json')]
# Serializing files: [PosixPath('pokemons/61-poliwhirl.json'), PosixPath('pokemons/61-poliwhirl-species.json')]
# Serializing files: [PosixPath('pokemons/52-meowth-species.json'), PosixPath('pokemons/52-meowth.json')]
# Serializing files: [PosixPath('pokemons/57-primeape-species.json'), PosixPath('pokemons/57-primeape.json')]
# Serializing files: [PosixPath('pokemons/55-golduck.json'), PosixPath('pokemons/55-golduck-species.json')]
# Serializing files: [PosixPath('pokemons/54-psyduck.json'), PosixPath('pokemons/54-psyduck-species.json')]
# Serializing files: [PosixPath('pokemons/65-alakazam-species.json'), PosixPath('pokemons/65-alakazam.json')]
# Serializing files: [PosixPath('pokemons/73-tentacruel-species.json'), PosixPath('pokemons/73-tentacruel.json')]
# Serializing files: [PosixPath('pokemons/59-arcanine.json'), PosixPath('pokemons/59-arcanine-species.json')]
# Serializing files: [PosixPath('pokemons/77-ponyta.json'), PosixPath('pokemons/77-ponyta-species.json')]
# Serializing files: [PosixPath('pokemons/68-machamp-species.json'), PosixPath('pokemons/68-machamp.json')]
# Serializing files: [PosixPath('pokemons/94-gengar-species.json'), PosixPath('pokemons/94-gengar.json')]
# Serializing files: [PosixPath('pokemons/60-poliwag-species.json'), PosixPath('pokemons/60-poliwag.json')]
# Serializing files: [PosixPath('pokemons/58-growlithe-species.json'), PosixPath('pokemons/58-growlithe.json')]
# Serializing files: [PosixPath('pokemons/56-mankey-species.json'), PosixPath('pokemons/56-mankey.json')]
# Serializing files: [PosixPath('pokemons/53-persian.json'), PosixPath('pokemons/53-persian-species.json')]
# Serializing files: [PosixPath('pokemons/92-gastly.json'), PosixPath('pokemons/92-gastly-species.json')]
# Serializing files: [PosixPath('pokemons/72-tentacool.json'), PosixPath('pokemons/72-tentacool-species.json')]
# Serializing files: [PosixPath('pokemons/51-dugtrio.json'), PosixPath('pokemons/51-dugtrio-species.json')]
# Serializing files: [PosixPath('pokemons/66-machop.json'), PosixPath('pokemons/66-machop-species.json')]
# Serializing files: [PosixPath('pokemons/64-kadabra.json'), PosixPath('pokemons/64-kadabra-species.json')]
# Serializing files: [PosixPath('pokemons/84-doduo-species.json'), PosixPath('pokemons/84-doduo.json')]
# Serializing files: [PosixPath('pokemons/71-victreebel-species.json'), PosixPath('pokemons/71-victreebel.json')]
# Serializing files: [PosixPath('pokemons/79-slowpoke.json'), PosixPath('pokemons/79-slowpoke-species.json')]
# Serializing files: [PosixPath('pokemons/74-geodude-species.json'), PosixPath('pokemons/74-geodude.json')]
# Serializing files: [PosixPath('pokemons/76-golem.json'), PosixPath('pokemons/76-golem-species.json')]
# Serializing files: [PosixPath('pokemons/67-machoke.json'), PosixPath('pokemons/67-machoke-species.json')]
# Serializing files: [PosixPath('pokemons/96-drowzee.json'), PosixPath('pokemons/96-drowzee-species.json')]
# Serializing files: [PosixPath('pokemons/78-rapidash.json'), PosixPath('pokemons/78-rapidash-species.json')]
# Serializing files: [PosixPath('pokemons/88-grimer-species.json'), PosixPath('pokemons/88-grimer.json')]
# Serializing files: [PosixPath('pokemons/82-magneton.json'), PosixPath('pokemons/82-magneton-species.json')]
# Serializing files: [PosixPath('pokemons/75-graveler-species.json'), PosixPath('pokemons/75-graveler.json')]
# Serializing files: [PosixPath('pokemons/99-kingler.json'), PosixPath('pokemons/99-kingler-species.json')]
# Serializing files: [PosixPath('pokemons/98-krabby.json'), PosixPath('pokemons/98-krabby-species.json')]
# Serializing files: [PosixPath('pokemons/83-farfetchd.json'), PosixPath('pokemons/83-farfetchd-species.json')]
# Serializing files: [PosixPath('pokemons/93-haunter-species.json'), PosixPath('pokemons/93-haunter.json')]
# Serializing files: [PosixPath('pokemons/70-weepinbell-species.json'), PosixPath('pokemons/70-weepinbell.json')]
# Serializing files: [PosixPath('pokemons/90-shellder-species.json'), PosixPath('pokemons/90-shellder.json')]
# Serializing files: [PosixPath('pokemons/80-slowbro.json'), PosixPath('pokemons/80-slowbro-species.json')]
# Serializing files: [PosixPath('pokemons/89-muk-species.json'), PosixPath('pokemons/89-muk.json')]
# Serializing files: [PosixPath('pokemons/69-bellsprout-species.json'), PosixPath('pokemons/69-bellsprout.json')]
# Serializing files: [PosixPath('pokemons/63-abra-species.json'), PosixPath('pokemons/63-abra.json')]
# Serializing files: [PosixPath('pokemons/87-dewgong-species.json'), PosixPath('pokemons/87-dewgong.json')]
# Serializing files: [PosixPath('pokemons/97-hypno-species.json'), PosixPath('pokemons/97-hypno.json')]
# Serializing files: [PosixPath('pokemons/91-cloyster-species.json'), PosixPath('pokemons/91-cloyster.json')]
# Serializing files: [PosixPath('pokemons/62-poliwrath.json'), PosixPath('pokemons/62-poliwrath-species.json')]
# Serializing files: [PosixPath('pokemons/85-dodrio-species.json'), PosixPath('pokemons/85-dodrio.json')]
# Serializing files: [PosixPath('pokemons/95-onix.json'), PosixPath('pokemons/95-onix-species.json')]
# Serializing files: [PosixPath('pokemons/100-voltorb-species.json'), PosixPath('pokemons/100-voltorb.json')]
# Serializing files: [PosixPath('pokemons/107-hitmonchan-species.json'), PosixPath('pokemons/107-hitmonchan.json')]
# Serializing files: [PosixPath('pokemons/113-chansey.json'), PosixPath('pokemons/113-chansey-species.json')]
# Serializing files: [PosixPath('pokemons/115-kangaskhan-species.json'), PosixPath('pokemons/115-kangaskhan.json')]
# Serializing files: [PosixPath('pokemons/103-exeggutor-species.json'), PosixPath('pokemons/103-exeggutor.json')]
# Serializing files: [PosixPath('pokemons/109-koffing.json'), PosixPath('pokemons/109-koffing-species.json')]
# Serializing files: [PosixPath('pokemons/101-electrode-species.json'), PosixPath('pokemons/101-electrode.json')]
# Serializing files: [PosixPath('pokemons/102-exeggcute-species.json'), PosixPath('pokemons/102-exeggcute.json')]
# Serializing files: [PosixPath('pokemons/111-rhyhorn-species.json'), PosixPath('pokemons/111-rhyhorn.json')]
# Serializing files: [PosixPath('pokemons/112-rhydon.json'), PosixPath('pokemons/112-rhydon-species.json')]
# Serializing files: [PosixPath('pokemons/105-marowak.json'), PosixPath('pokemons/105-marowak-species.json')]
# Serializing files: [PosixPath('pokemons/140-kabuto.json'), PosixPath('pokemons/140-kabuto-species.json')]
# Serializing files: [PosixPath('pokemons/121-starmie-species.json'), PosixPath('pokemons/121-starmie.json')]
# Serializing files: [PosixPath('pokemons/110-weezing-species.json'), PosixPath('pokemons/110-weezing.json')]
# Serializing files: [PosixPath('pokemons/127-pinsir-species.json'), PosixPath('pokemons/127-pinsir.json')]
# Serializing files: [PosixPath('pokemons/120-staryu.json'), PosixPath('pokemons/120-staryu-species.json')]
# Serializing files: [PosixPath('pokemons/126-magmar.json'), PosixPath('pokemons/126-magmar-species.json')]
# Serializing files: [PosixPath('pokemons/117-seadra.json'), PosixPath('pokemons/117-seadra-species.json')]
# Serializing files: [PosixPath('pokemons/125-electabuzz.json'), PosixPath('pokemons/125-electabuzz-species.json')]
# Serializing files: [PosixPath('pokemons/135-jolteon-species.json'), PosixPath('pokemons/135-jolteon.json')]
# Serializing files: [PosixPath('pokemons/108-lickitung.json'), PosixPath('pokemons/108-lickitung-species.json')]
# Serializing files: [PosixPath('pokemons/104-cubone.json'), PosixPath('pokemons/104-cubone-species.json')]
# Serializing files: [PosixPath('pokemons/106-hitmonlee.json'), PosixPath('pokemons/106-hitmonlee-species.json')]
# Serializing files: [PosixPath('pokemons/116-horsea-species.json'), PosixPath('pokemons/116-horsea.json')]
# Serializing files: [PosixPath('pokemons/132-ditto-species.json'), PosixPath('pokemons/132-ditto.json')]
# Serializing files: [PosixPath('pokemons/124-jynx.json'), PosixPath('pokemons/124-jynx-species.json')]
# Serializing files: [PosixPath('pokemons/119-seaking-species.json'), PosixPath('pokemons/119-seaking.json')]
# Serializing files: [PosixPath('pokemons/146-moltres-species.json'), PosixPath('pokemons/146-moltres.json')]
# Serializing files: [PosixPath('pokemons/118-goldeen.json'), PosixPath('pokemons/118-goldeen-species.json')]
# Serializing files: [PosixPath('pokemons/114-tangela.json'), PosixPath('pokemons/114-tangela-species.json')]
# Serializing files: [PosixPath('pokemons/130-gyarados-species.json'), PosixPath('pokemons/130-gyarados.json')]
# Serializing files: [PosixPath('pokemons/128-tauros-species.json'), PosixPath('pokemons/128-tauros.json')]
# Serializing files: [PosixPath('pokemons/143-snorlax.json'), PosixPath('pokemons/143-snorlax-species.json')]
# Serializing files: [PosixPath('pokemons/122-mr-mime.json'), PosixPath('pokemons/122-mr-mime-species.json')]
# Serializing files: [PosixPath('pokemons/133-eevee-species.json'), PosixPath('pokemons/133-eevee.json')]
# Serializing files: [PosixPath('pokemons/123-scyther-species.json'), PosixPath('pokemons/123-scyther.json')]
# Serializing files: [PosixPath('pokemons/131-lapras.json'), PosixPath('pokemons/131-lapras-species.json')]
# Serializing files: [PosixPath('pokemons/129-magikarp.json'), PosixPath('pokemons/129-magikarp-species.json')]
# Serializing files: [PosixPath('pokemons/145-zapdos-species.json'), PosixPath('pokemons/145-zapdos.json')]
# Serializing files: [PosixPath('pokemons/134-vaporeon-species.json'), PosixPath('pokemons/134-vaporeon.json')]
# Serializing files: [PosixPath('pokemons/137-porygon.json'), PosixPath('pokemons/137-porygon-species.json')]
# Serializing files: [PosixPath('pokemons/150-mewtwo.json'), PosixPath('pokemons/150-mewtwo-species.json')]
# Serializing files: [PosixPath('pokemons/136-flareon-species.json'), PosixPath('pokemons/136-flareon.json')]
# Serializing files: [PosixPath('pokemons/138-omanyte.json'), PosixPath('pokemons/138-omanyte-species.json')]
# Serializing files: [PosixPath('pokemons/142-aerodactyl.json'), PosixPath('pokemons/142-aerodactyl-species.json')]
# Serializing files: [PosixPath('pokemons/147-dratini.json'), PosixPath('pokemons/147-dratini-species.json')]
# Serializing files: [PosixPath('pokemons/144-articuno.json'), PosixPath('pokemons/144-articuno-species.json')]
# Serializing files: [PosixPath('pokemons/139-omastar.json'), PosixPath('pokemons/139-omastar-species.json')]
# Serializing files: [PosixPath('pokemons/148-dragonair-species.json'), PosixPath('pokemons/148-dragonair.json')]
# Serializing files: [PosixPath('pokemons/141-kabutops.json'), PosixPath('pokemons/141-kabutops-species.json')]
# Serializing files: [PosixPath('pokemons/149-dragonite-species.json'), PosixPath('pokemons/149-dragonite.json')]
# Serializing files: [PosixPath('pokemons/152-chikorita.json'), PosixPath('pokemons/152-chikorita-species.json')]
# Serializing files: [PosixPath('pokemons/151-mew.json'), PosixPath('pokemons/151-mew-species.json')]
# Serializing files: [PosixPath('pokemons/154-meganium.json'), PosixPath('pokemons/154-meganium-species.json')]
# Serializing files: [PosixPath('pokemons/153-bayleef-species.json'), PosixPath('pokemons/153-bayleef.json')]
# Serializing files: [PosixPath('pokemons/155-cyndaquil-species.json'), PosixPath('pokemons/155-cyndaquil.json')]
# Serializing files: [PosixPath('pokemons/158-totodile-species.json'), PosixPath('pokemons/158-totodile.json')]
# Serializing files: [PosixPath('pokemons/160-feraligatr.json'), PosixPath('pokemons/160-feraligatr-species.json')]
# Serializing files: [PosixPath('pokemons/172-pichu.json'), PosixPath('pokemons/172-pichu-species.json')]
# Serializing files: [PosixPath('pokemons/166-ledian-species.json'), PosixPath('pokemons/166-ledian.json')]
# Serializing files: [PosixPath('pokemons/157-typhlosion-species.json'), PosixPath('pokemons/157-typhlosion.json')]
# Serializing files: [PosixPath('pokemons/163-hoothoot-species.json'), PosixPath('pokemons/163-hoothoot.json')]
# Serializing files: [PosixPath('pokemons/168-ariados-species.json'), PosixPath('pokemons/168-ariados.json')]
# Serializing files: [PosixPath('pokemons/170-chinchou.json'), PosixPath('pokemons/170-chinchou-species.json')]
# Serializing files: [PosixPath('pokemons/185-sudowoodo-species.json'), PosixPath('pokemons/185-sudowoodo.json')]
# Serializing files: [PosixPath('pokemons/156-quilava-species.json'), PosixPath('pokemons/156-quilava.json')]
# Serializing files: [PosixPath('pokemons/162-furret-species.json'), PosixPath('pokemons/162-furret.json')]
# Serializing files: [PosixPath('pokemons/159-croconaw.json'), PosixPath('pokemons/159-croconaw-species.json')]
# Serializing files: [PosixPath('pokemons/167-spinarak.json'), PosixPath('pokemons/167-spinarak-species.json')]
# Serializing files: [PosixPath('pokemons/181-ampharos.json'), PosixPath('pokemons/181-ampharos-species.json')]
# Serializing files: [PosixPath('pokemons/173-cleffa-species.json'), PosixPath('pokemons/173-cleffa.json')]
# Serializing files: [PosixPath('pokemons/164-noctowl-species.json'), PosixPath('pokemons/164-noctowl.json')]
# Serializing files: [PosixPath('pokemons/165-ledyba.json'), PosixPath('pokemons/165-ledyba-species.json')]
# Serializing files: [PosixPath('pokemons/182-bellossom.json'), PosixPath('pokemons/182-bellossom-species.json')]
# Serializing files: [PosixPath('pokemons/174-igglybuff-species.json'), PosixPath('pokemons/174-igglybuff.json')]
# Serializing files: [PosixPath('pokemons/176-togetic.json'), PosixPath('pokemons/176-togetic-species.json')]
# Serializing files: [PosixPath('pokemons/161-sentret-species.json'), PosixPath('pokemons/161-sentret.json')]
# Serializing files: [PosixPath('pokemons/171-lanturn-species.json'), PosixPath('pokemons/171-lanturn.json')]
# Serializing files: [PosixPath('pokemons/193-yanma.json'), PosixPath('pokemons/193-yanma-species.json')]
# Serializing files: [PosixPath('pokemons/183-marill.json'), PosixPath('pokemons/183-marill-species.json')]
# Serializing files: [PosixPath('pokemons/192-sunflora-species.json'), PosixPath('pokemons/192-sunflora.json')]
# Serializing files: [PosixPath('pokemons/180-flaaffy-species.json'), PosixPath('pokemons/180-flaaffy.json')]
# Serializing files: [PosixPath('pokemons/195-quagsire-species.json'), PosixPath('pokemons/195-quagsire.json')]
# Serializing files: [PosixPath('pokemons/169-crobat-species.json'), PosixPath('pokemons/169-crobat.json')]
# Serializing files: [PosixPath('pokemons/184-azumarill-species.json'), PosixPath('pokemons/184-azumarill.json')]
# Serializing files: [PosixPath('pokemons/186-politoed.json'), PosixPath('pokemons/186-politoed-species.json')]
# Serializing files: [PosixPath('pokemons/179-mareep.json'), PosixPath('pokemons/179-mareep-species.json')]
# Serializing files: [PosixPath('pokemons/175-togepi-species.json'), PosixPath('pokemons/175-togepi.json')]
# Serializing files: [PosixPath('pokemons/178-xatu-species.json'), PosixPath('pokemons/178-xatu.json')]
# Serializing files: [PosixPath('pokemons/177-natu-species.json'), PosixPath('pokemons/177-natu.json')]
# Serializing files: [PosixPath('pokemons/198-murkrow-species.json'), PosixPath('pokemons/198-murkrow.json')]
# Serializing files: [PosixPath('pokemons/187-hoppip.json'), PosixPath('pokemons/187-hoppip-species.json')]
# Serializing files: [PosixPath('pokemons/194-wooper-species.json'), PosixPath('pokemons/194-wooper.json')]
# Serializing files: [PosixPath('pokemons/197-umbreon.json'), PosixPath('pokemons/197-umbreon-species.json')]
# Serializing files: [PosixPath('pokemons/189-jumpluff.json'), PosixPath('pokemons/189-jumpluff-species.json')]
# Serializing files: [PosixPath('pokemons/188-skiploom.json'), PosixPath('pokemons/188-skiploom-species.json')]
# Serializing files: [PosixPath('pokemons/191-sunkern.json'), PosixPath('pokemons/191-sunkern-species.json')]
# Serializing files: [PosixPath('pokemons/199-slowking-species.json'), PosixPath('pokemons/199-slowking.json')]
# Serializing files: [PosixPath('pokemons/190-aipom-species.json'), PosixPath('pokemons/190-aipom.json')]
# Serializing files: [PosixPath('pokemons/196-espeon.json'), PosixPath('pokemons/196-espeon-species.json')]
# Serializing files: [PosixPath('pokemons/200-misdreavus-species.json'), PosixPath('pokemons/200-misdreavus.json')]
# Serializing files: [PosixPath('pokemons/202-wobbuffet.json'), PosixPath('pokemons/202-wobbuffet-species.json')]
# Serializing files: [PosixPath('pokemons/203-girafarig-species.json'), PosixPath('pokemons/203-girafarig.json')]
# Serializing files: [PosixPath('pokemons/201-unown-species.json'), PosixPath('pokemons/201-unown.json')]
# Serializing files: [PosixPath('pokemons/205-forretress.json'), PosixPath('pokemons/205-forretress-species.json')]
# Serializing files: [PosixPath('pokemons/214-heracross-species.json'), PosixPath('pokemons/214-heracross.json')]
# Serializing files: [PosixPath('pokemons/215-sneasel-species.json'), PosixPath('pokemons/215-sneasel.json')]
# Serializing files: [PosixPath('pokemons/218-slugma.json'), PosixPath('pokemons/218-slugma-species.json')]
# Serializing files: [PosixPath('pokemons/207-gligar.json'), PosixPath('pokemons/207-gligar-species.json')]
# Serializing files: [PosixPath('pokemons/210-granbull.json'), PosixPath('pokemons/210-granbull-species.json')]
# Serializing files: [PosixPath('pokemons/211-qwilfish.json'), PosixPath('pokemons/211-qwilfish-species.json')]
# Serializing files: [PosixPath('pokemons/213-shuckle.json'), PosixPath('pokemons/213-shuckle-species.json')]
# Serializing files: [PosixPath('pokemons/223-remoraid.json'), PosixPath('pokemons/223-remoraid-species.json')]
# Serializing files: [PosixPath('pokemons/222-corsola-species.json'), PosixPath('pokemons/222-corsola.json')]
# Serializing files: [PosixPath('pokemons/206-dunsparce.json'), PosixPath('pokemons/206-dunsparce-species.json')]
# Serializing files: [PosixPath('pokemons/208-steelix-species.json'), PosixPath('pokemons/208-steelix.json')]
# Serializing files: [PosixPath('pokemons/227-skarmory-species.json'), PosixPath('pokemons/227-skarmory.json')]
# Serializing files: [PosixPath('pokemons/204-pineco-species.json'), PosixPath('pokemons/204-pineco.json')]
# Serializing files: [PosixPath('pokemons/212-scizor.json'), PosixPath('pokemons/212-scizor-species.json')]
# Serializing files: [PosixPath('pokemons/219-magcargo.json'), PosixPath('pokemons/219-magcargo-species.json')]
# Serializing files: [PosixPath('pokemons/221-piloswine-species.json'), PosixPath('pokemons/221-piloswine.json')]
# Serializing files: [PosixPath('pokemons/209-snubbull-species.json'), PosixPath('pokemons/209-snubbull.json')]
# Serializing files: [PosixPath('pokemons/225-delibird-species.json'), PosixPath('pokemons/225-delibird.json')]
# Serializing files: [PosixPath('pokemons/237-hitmontop.json'), PosixPath('pokemons/237-hitmontop-species.json')]
# Serializing files: [PosixPath('pokemons/232-donphan.json'), PosixPath('pokemons/232-donphan-species.json')]
# Serializing files: [PosixPath('pokemons/236-tyrogue-species.json'), PosixPath('pokemons/236-tyrogue.json')]
# Serializing files: [PosixPath('pokemons/233-porygon2.json'), PosixPath('pokemons/233-porygon2-species.json')]
# Serializing files: [PosixPath('pokemons/224-octillery-species.json'), PosixPath('pokemons/224-octillery.json')]
# Serializing files: [PosixPath('pokemons/242-blissey-species.json'), PosixPath('pokemons/242-blissey.json')]
# Serializing files: [PosixPath('pokemons/216-teddiursa.json'), PosixPath('pokemons/216-teddiursa-species.json')]
# Serializing files: [PosixPath('pokemons/217-ursaring-species.json'), PosixPath('pokemons/217-ursaring.json')]
# Serializing files: [PosixPath('pokemons/228-houndour.json'), PosixPath('pokemons/228-houndour-species.json')]
# Serializing files: [PosixPath('pokemons/234-stantler.json'), PosixPath('pokemons/234-stantler-species.json')]
# Serializing files: [PosixPath('pokemons/226-mantine-species.json'), PosixPath('pokemons/226-mantine.json')]
# Serializing files: [PosixPath('pokemons/246-larvitar.json'), PosixPath('pokemons/246-larvitar-species.json')]
# Serializing files: [PosixPath('pokemons/229-houndoom.json'), PosixPath('pokemons/229-houndoom-species.json')]
# Serializing files: [PosixPath('pokemons/230-kingdra-species.json'), PosixPath('pokemons/230-kingdra.json')]
# Serializing files: [PosixPath('pokemons/245-suicune-species.json'), PosixPath('pokemons/245-suicune.json')]
# Serializing files: [PosixPath('pokemons/220-swinub-species.json'), PosixPath('pokemons/220-swinub.json')]
# Serializing files: [PosixPath('pokemons/231-phanpy.json'), PosixPath('pokemons/231-phanpy-species.json')]
# Serializing files: [PosixPath('pokemons/248-tyranitar.json'), PosixPath('pokemons/248-tyranitar-species.json')]
# Serializing files: [PosixPath('pokemons/240-magby-species.json'), PosixPath('pokemons/240-magby.json')]
# Serializing files: [PosixPath('pokemons/244-entei.json'), PosixPath('pokemons/244-entei-species.json')]
# Serializing files: [PosixPath('pokemons/235-smeargle-species.json'), PosixPath('pokemons/235-smeargle.json')]
# Serializing files: [PosixPath('pokemons/247-pupitar.json'), PosixPath('pokemons/247-pupitar-species.json')]
# Serializing files: [PosixPath('pokemons/241-miltank-species.json'), PosixPath('pokemons/241-miltank.json')]
# Serializing files: [PosixPath('pokemons/238-smoochum-species.json'), PosixPath('pokemons/238-smoochum.json')]
# Serializing files: [PosixPath('pokemons/243-raikou.json'), PosixPath('pokemons/243-raikou-species.json')]
# Serializing files: [PosixPath('pokemons/249-lugia-species.json'), PosixPath('pokemons/249-lugia.json')]
# Serializing files: [PosixPath('pokemons/239-elekid.json'), PosixPath('pokemons/239-elekid-species.json')]
# Serializing files: [PosixPath('pokemons/250-ho-oh-species.json'), PosixPath('pokemons/250-ho-oh.json')]
# Serializing files: [PosixPath('pokemons/251-celebi-species.json'), PosixPath('pokemons/251-celebi.json')]
# Serializing files: [PosixPath('pokemons/252-treecko-species.json'), PosixPath('pokemons/252-treecko.json')]
# Serializing files: [PosixPath('pokemons/253-grovyle.json'), PosixPath('pokemons/253-grovyle-species.json')]
# Serializing files: [PosixPath('pokemons/254-sceptile-species.json'), PosixPath('pokemons/254-sceptile.json')]
# Serializing files: [PosixPath('pokemons/259-marshtomp.json'), PosixPath('pokemons/259-marshtomp-species.json')]
# Serializing files: [PosixPath('pokemons/255-torchic-species.json'), PosixPath('pokemons/255-torchic.json')]
# Serializing files: [PosixPath('pokemons/257-blaziken-species.json'), PosixPath('pokemons/257-blaziken.json')]
# Serializing files: [PosixPath('pokemons/262-mightyena.json'), PosixPath('pokemons/262-mightyena-species.json')]
# Serializing files: [PosixPath('pokemons/258-mudkip-species.json'), PosixPath('pokemons/258-mudkip.json')]
# Serializing files: [PosixPath('pokemons/266-silcoon.json'), PosixPath('pokemons/266-silcoon-species.json')]
# Serializing files: [PosixPath('pokemons/264-linoone-species.json'), PosixPath('pokemons/264-linoone.json')]
# Serializing files: [PosixPath('pokemons/265-wurmple-species.json'), PosixPath('pokemons/265-wurmple.json')]
# Serializing files: [PosixPath('pokemons/256-combusken-species.json'), PosixPath('pokemons/256-combusken.json')]
# Serializing files: [PosixPath('pokemons/278-wingull-species.json'), PosixPath('pokemons/278-wingull.json')]
# Serializing files: [PosixPath('pokemons/271-lombre.json'), PosixPath('pokemons/271-lombre-species.json')]
# Serializing files: [PosixPath('pokemons/261-poochyena-species.json'), PosixPath('pokemons/261-poochyena.json')]
# Serializing files: [PosixPath('pokemons/267-beautifly.json'), PosixPath('pokemons/267-beautifly-species.json')]
# Serializing files: [PosixPath('pokemons/269-dustox.json'), PosixPath('pokemons/269-dustox-species.json')]
# Serializing files: [PosixPath('pokemons/260-swampert-species.json'), PosixPath('pokemons/260-swampert.json')]
# Serializing files: [PosixPath('pokemons/268-cascoon.json'), PosixPath('pokemons/268-cascoon-species.json')]
# Serializing files: [PosixPath('pokemons/263-zigzagoon-species.json'), PosixPath('pokemons/263-zigzagoon.json')]
# Serializing files: [PosixPath('pokemons/272-ludicolo.json'), PosixPath('pokemons/272-ludicolo-species.json')]
# Serializing files: [PosixPath('pokemons/274-nuzleaf-species.json'), PosixPath('pokemons/274-nuzleaf.json')]
# Serializing files: [PosixPath('pokemons/276-taillow.json'), PosixPath('pokemons/276-taillow-species.json')]
# Serializing files: [PosixPath('pokemons/270-lotad.json'), PosixPath('pokemons/270-lotad-species.json')]
# Serializing files: [PosixPath('pokemons/283-surskit-species.json'), PosixPath('pokemons/283-surskit.json')]
# Serializing files: [PosixPath('pokemons/282-gardevoir-species.json'), PosixPath('pokemons/282-gardevoir.json')]
# Serializing files: [PosixPath('pokemons/273-seedot.json'), PosixPath('pokemons/273-seedot-species.json')]
# Serializing files: [PosixPath('pokemons/280-ralts.json'), PosixPath('pokemons/280-ralts-species.json')]
# Serializing files: [PosixPath('pokemons/286-breloom.json'), PosixPath('pokemons/286-breloom-species.json')]
# Serializing files: [PosixPath('pokemons/275-shiftry.json'), PosixPath('pokemons/275-shiftry-species.json')]
# Serializing files: [PosixPath('pokemons/284-masquerain.json'), PosixPath('pokemons/284-masquerain-species.json')]
# Serializing files: [PosixPath('pokemons/281-kirlia-species.json'), PosixPath('pokemons/281-kirlia.json')]
# Serializing files: [PosixPath('pokemons/291-ninjask-species.json'), PosixPath('pokemons/291-ninjask.json')]
# Serializing files: [PosixPath('pokemons/287-slakoth-species.json'), PosixPath('pokemons/287-slakoth.json')]
# Serializing files: [PosixPath('pokemons/279-pelipper-species.json'), PosixPath('pokemons/279-pelipper.json')]
# Serializing files: [PosixPath('pokemons/292-shedinja-species.json'), PosixPath('pokemons/292-shedinja.json')]
# Serializing files: [PosixPath('pokemons/289-slaking.json'), PosixPath('pokemons/289-slaking-species.json')]
# Serializing files: [PosixPath('pokemons/293-whismur-species.json'), PosixPath('pokemons/293-whismur.json')]
# Serializing files: [PosixPath('pokemons/295-exploud.json'), PosixPath('pokemons/295-exploud-species.json')]
# Serializing files: [PosixPath('pokemons/288-vigoroth.json'), PosixPath('pokemons/288-vigoroth-species.json')]
# Serializing files: [PosixPath('pokemons/285-shroomish.json'), PosixPath('pokemons/285-shroomish-species.json')]
# Serializing files: [PosixPath('pokemons/277-swellow.json'), PosixPath('pokemons/277-swellow-species.json')]
# Serializing files: [PosixPath('pokemons/296-makuhita.json'), PosixPath('pokemons/296-makuhita-species.json')]
# Serializing files: [PosixPath('pokemons/294-loudred.json'), PosixPath('pokemons/294-loudred-species.json')]
# Serializing files: [PosixPath('pokemons/290-nincada.json'), PosixPath('pokemons/290-nincada-species.json')]
# Serializing files: [PosixPath('pokemons/299-nosepass.json'), PosixPath('pokemons/299-nosepass-species.json')]
# Serializing files: [PosixPath('pokemons/297-hariyama.json'), PosixPath('pokemons/297-hariyama-species.json')]
# Serializing files: [PosixPath('pokemons/298-azurill-species.json'), PosixPath('pokemons/298-azurill.json')]
# Serializing files: [PosixPath('pokemons/300-skitty-species.json'), PosixPath('pokemons/300-skitty.json')]
# Serializing files: [PosixPath('pokemons/301-delcatty-species.json'), PosixPath('pokemons/301-delcatty.json')]
# Serializing files: [PosixPath('pokemons/303-mawile-species.json'), PosixPath('pokemons/303-mawile.json')]
# Serializing files: [PosixPath('pokemons/302-sableye-species.json'), PosixPath('pokemons/302-sableye.json')]
# Serializing files: [PosixPath('pokemons/304-aron-species.json'), PosixPath('pokemons/304-aron.json')]
# Serializing files: [PosixPath('pokemons/306-aggron-species.json'), PosixPath('pokemons/306-aggron.json')]
# Serializing files: [PosixPath('pokemons/310-manectric.json'), PosixPath('pokemons/310-manectric-species.json')]
# Serializing files: [PosixPath('pokemons/305-lairon.json'), PosixPath('pokemons/305-lairon-species.json')]
# Serializing files: [PosixPath('pokemons/316-gulpin-species.json'), PosixPath('pokemons/316-gulpin.json')]
# Serializing files: [PosixPath('pokemons/307-meditite.json'), PosixPath('pokemons/307-meditite-species.json')]
# Serializing files: [PosixPath('pokemons/308-medicham-species.json'), PosixPath('pokemons/308-medicham.json')]
# Serializing files: [PosixPath('pokemons/309-electrike-species.json'), PosixPath('pokemons/309-electrike.json')]
# Serializing files: [PosixPath('pokemons/314-illumise-species.json'), PosixPath('pokemons/314-illumise.json')]
# Serializing files: [PosixPath('pokemons/311-plusle-species.json'), PosixPath('pokemons/311-plusle.json')]
# Serializing files: [PosixPath('pokemons/313-volbeat.json'), PosixPath('pokemons/313-volbeat-species.json')]
# Serializing files: [PosixPath('pokemons/321-wailord-species.json'), PosixPath('pokemons/321-wailord.json')]
# Serializing files: [PosixPath('pokemons/312-minun.json'), PosixPath('pokemons/312-minun-species.json')]
# Serializing files: [PosixPath('pokemons/325-spoink-species.json'), PosixPath('pokemons/325-spoink.json')]
# Serializing files: [PosixPath('pokemons/320-wailmer.json'), PosixPath('pokemons/320-wailmer-species.json')]
# Serializing files: [PosixPath('pokemons/317-swalot-species.json'), PosixPath('pokemons/317-swalot.json')]
# Serializing files: [PosixPath('pokemons/318-carvanha-species.json'), PosixPath('pokemons/318-carvanha.json')]
# Serializing files: [PosixPath('pokemons/315-roselia.json'), PosixPath('pokemons/315-roselia-species.json')]
# Serializing files: [PosixPath('pokemons/322-numel.json'), PosixPath('pokemons/322-numel-species.json')]
# Serializing files: [PosixPath('pokemons/329-vibrava-species.json'), PosixPath('pokemons/329-vibrava.json')]
# Serializing files: [PosixPath('pokemons/330-flygon.json'), PosixPath('pokemons/330-flygon-species.json')]
# Serializing files: [PosixPath('pokemons/319-sharpedo.json'), PosixPath('pokemons/319-sharpedo-species.json')]
# Serializing files: [PosixPath('pokemons/331-cacnea-species.json'), PosixPath('pokemons/331-cacnea.json')]
# Serializing files: [PosixPath('pokemons/328-trapinch.json'), PosixPath('pokemons/328-trapinch-species.json')]
# Serializing files: [PosixPath('pokemons/323-camerupt.json'), PosixPath('pokemons/323-camerupt-species.json')]
# Serializing files: [PosixPath('pokemons/327-spinda-species.json'), PosixPath('pokemons/327-spinda.json')]
# Serializing files: [PosixPath('pokemons/341-corphish-species.json'), PosixPath('pokemons/341-corphish.json')]
# Serializing files: [PosixPath('pokemons/326-grumpig.json'), PosixPath('pokemons/326-grumpig-species.json')]
# Serializing files: [PosixPath('pokemons/334-altaria-species.json'), PosixPath('pokemons/334-altaria.json')]
# Serializing files: [PosixPath('pokemons/348-armaldo-species.json'), PosixPath('pokemons/348-armaldo.json')]
# Serializing files: [PosixPath('pokemons/337-lunatone.json'), PosixPath('pokemons/337-lunatone-species.json')]
# Serializing files: [PosixPath('pokemons/342-crawdaunt-species.json'), PosixPath('pokemons/342-crawdaunt.json')]
# Serializing files: [PosixPath('pokemons/336-seviper.json'), PosixPath('pokemons/336-seviper-species.json')]
# Serializing files: [PosixPath('pokemons/324-torkoal.json'), PosixPath('pokemons/324-torkoal-species.json')]
# Serializing files: [PosixPath('pokemons/335-zangoose.json'), PosixPath('pokemons/335-zangoose-species.json')]
# Serializing files: [PosixPath('pokemons/333-swablu-species.json'), PosixPath('pokemons/333-swablu.json')]
# Serializing files: [PosixPath('pokemons/340-whiscash-species.json'), PosixPath('pokemons/340-whiscash.json')]
# Serializing files: [PosixPath('pokemons/347-anorith-species.json'), PosixPath('pokemons/347-anorith.json')]
# Serializing files: [PosixPath('pokemons/332-cacturne-species.json'), PosixPath('pokemons/332-cacturne.json')]
# Serializing files: [PosixPath('pokemons/345-lileep.json'), PosixPath('pokemons/345-lileep-species.json')]
# Serializing files: [PosixPath('pokemons/343-baltoy.json'), PosixPath('pokemons/343-baltoy-species.json')]
# Serializing files: [PosixPath('pokemons/344-claydol.json'), PosixPath('pokemons/344-claydol-species.json')]
# Serializing files: [PosixPath('pokemons/338-solrock.json'), PosixPath('pokemons/338-solrock-species.json')]
# Serializing files: [PosixPath('pokemons/346-cradily-species.json'), PosixPath('pokemons/346-cradily.json')]
# Serializing files: [PosixPath('pokemons/339-barboach-species.json'), PosixPath('pokemons/339-barboach.json')]
# Serializing files: [PosixPath('pokemons/350-milotic-species.json'), PosixPath('pokemons/350-milotic.json')]
# Serializing files: [PosixPath('pokemons/349-feebas-species.json'), PosixPath('pokemons/349-feebas.json')]
# Serializing files: [PosixPath('pokemons/353-shuppet.json'), PosixPath('pokemons/353-shuppet-species.json')]
# Serializing files: [PosixPath('pokemons/351-castform.json'), PosixPath('pokemons/351-castform-species.json')]
# Serializing files: [PosixPath('pokemons/352-kecleon-species.json'), PosixPath('pokemons/352-kecleon.json')]
# Serializing files: [PosixPath('pokemons/354-banette.json'), PosixPath('pokemons/354-banette-species.json')]
# Serializing files: [PosixPath('pokemons/359-absol.json'), PosixPath('pokemons/359-absol-species.json')]
# Serializing files: [PosixPath('pokemons/361-snorunt.json'), PosixPath('pokemons/361-snorunt-species.json')]
# Serializing files: [PosixPath('pokemons/355-duskull-species.json'), PosixPath('pokemons/355-duskull.json')]
# Serializing files: [PosixPath('pokemons/362-glalie.json'), PosixPath('pokemons/362-glalie-species.json')]
# Serializing files: [PosixPath('pokemons/360-wynaut.json'), PosixPath('pokemons/360-wynaut-species.json')]
# Serializing files: [PosixPath('pokemons/357-tropius-species.json'), PosixPath('pokemons/357-tropius.json')]
# Serializing files: [PosixPath('pokemons/356-dusclops.json'), PosixPath('pokemons/356-dusclops-species.json')]
# Serializing files: [PosixPath('pokemons/365-walrein-species.json'), PosixPath('pokemons/365-walrein.json')]
# Serializing files: [PosixPath('pokemons/366-clamperl-species.json'), PosixPath('pokemons/366-clamperl.json')]
# Serializing files: [PosixPath('pokemons/364-sealeo-species.json'), PosixPath('pokemons/364-sealeo.json')]
# Serializing files: [PosixPath('pokemons/369-relicanth.json'), PosixPath('pokemons/369-relicanth-species.json')]
# Serializing files: [PosixPath('pokemons/372-shelgon.json'), PosixPath('pokemons/372-shelgon-species.json')]
# Serializing files: [PosixPath('pokemons/368-gorebyss.json'), PosixPath('pokemons/368-gorebyss-species.json')]
# Serializing files: [PosixPath('pokemons/358-chimecho-species.json'), PosixPath('pokemons/358-chimecho.json')]
# Serializing files: [PosixPath('pokemons/363-spheal.json'), PosixPath('pokemons/363-spheal-species.json')]
# Serializing files: [PosixPath('pokemons/370-luvdisc.json'), PosixPath('pokemons/370-luvdisc-species.json')]
# Serializing files: [PosixPath('pokemons/373-salamence-species.json'), PosixPath('pokemons/373-salamence.json')]
# Serializing files: [PosixPath('pokemons/367-huntail.json'), PosixPath('pokemons/367-huntail-species.json')]
# Serializing files: [PosixPath('pokemons/384-rayquaza.json'), PosixPath('pokemons/384-rayquaza-species.json')]
# Serializing files: [PosixPath('pokemons/383-groudon.json'), PosixPath('pokemons/383-groudon-species.json')]
# Serializing files: [PosixPath('pokemons/375-metang-species.json'), PosixPath('pokemons/375-metang.json')]
# Serializing files: [PosixPath('pokemons/378-regice-species.json'), PosixPath('pokemons/378-regice.json')]
# Serializing files: [PosixPath('pokemons/382-kyogre.json'), PosixPath('pokemons/382-kyogre-species.json')]
# Serializing files: [PosixPath('pokemons/380-latias.json'), PosixPath('pokemons/380-latias-species.json')]
# Serializing files: [PosixPath('pokemons/371-bagon.json'), PosixPath('pokemons/371-bagon-species.json')]
# Serializing files: [PosixPath('pokemons/374-beldum-species.json'), PosixPath('pokemons/374-beldum.json')]
# Serializing files: [PosixPath('pokemons/385-jirachi.json'), PosixPath('pokemons/385-jirachi-species.json')]
# Serializing files: [PosixPath('pokemons/376-metagross.json'), PosixPath('pokemons/376-metagross-species.json')]
# Serializing files: [PosixPath('pokemons/386-deoxys-normal-species.json'), PosixPath('pokemons/386-deoxys-normal.json')]
# Serializing files: [PosixPath('pokemons/381-latios.json'), PosixPath('pokemons/381-latios-species.json')]
# Serializing files: [PosixPath('pokemons/388-grotle-species.json'), PosixPath('pokemons/388-grotle.json')]
# Serializing files: [PosixPath('pokemons/377-regirock.json'), PosixPath('pokemons/377-regirock-species.json')]
# Serializing files: [PosixPath('pokemons/387-turtwig-species.json'), PosixPath('pokemons/387-turtwig.json')]
# Serializing files: [PosixPath('pokemons/396-starly-species.json'), PosixPath('pokemons/396-starly.json')]
# Serializing files: [PosixPath('pokemons/393-piplup.json'), PosixPath('pokemons/393-piplup-species.json')]
# Serializing files: [PosixPath('pokemons/379-registeel.json'), PosixPath('pokemons/379-registeel-species.json')]
# Serializing files: [PosixPath('pokemons/389-torterra.json'), PosixPath('pokemons/389-torterra-species.json')]
# Serializing files: [PosixPath('pokemons/390-chimchar.json'), PosixPath('pokemons/390-chimchar-species.json')]
# Serializing files: [PosixPath('pokemons/391-monferno-species.json'), PosixPath('pokemons/391-monferno.json')]
# Serializing files: [PosixPath('pokemons/394-prinplup-species.json'), PosixPath('pokemons/394-prinplup.json')]
# Serializing files: [PosixPath('pokemons/395-empoleon-species.json'), PosixPath('pokemons/395-empoleon.json')]
# Serializing files: [PosixPath('pokemons/397-staravia.json'), PosixPath('pokemons/397-staravia-species.json')]
# Serializing files: [PosixPath('pokemons/392-infernape-species.json'), PosixPath('pokemons/392-infernape.json')]
# Serializing files: [PosixPath('pokemons/398-staraptor-species.json'), PosixPath('pokemons/398-staraptor.json')]
# Serializing files: [PosixPath('pokemons/399-bidoof.json'), PosixPath('pokemons/399-bidoof-species.json')]
# Serializing files: [PosixPath('pokemons/400-bibarel.json'), PosixPath('pokemons/400-bibarel-species.json')]
# Serializing files: [PosixPath('pokemons/403-shinx.json'), PosixPath('pokemons/403-shinx-species.json')]
# Serializing files: [PosixPath('pokemons/401-kricketot-species.json'), PosixPath('pokemons/401-kricketot.json')]
# Serializing files: [PosixPath('pokemons/402-kricketune.json'), PosixPath('pokemons/402-kricketune-species.json')]
# Serializing files: [PosixPath('pokemons/406-budew.json'), PosixPath('pokemons/406-budew-species.json')]
# Serializing files: [PosixPath('pokemons/405-luxray-species.json'), PosixPath('pokemons/405-luxray.json')]
# Serializing files: [PosixPath('pokemons/404-luxio-species.json'), PosixPath('pokemons/404-luxio.json')]
# Serializing files: [PosixPath('pokemons/408-cranidos-species.json'), PosixPath('pokemons/408-cranidos.json')]
# Serializing files: [PosixPath('pokemons/409-rampardos-species.json'), PosixPath('pokemons/409-rampardos.json')]
# Serializing files: [PosixPath('pokemons/407-roserade.json'), PosixPath('pokemons/407-roserade-species.json')]
# Serializing files: [PosixPath('pokemons/411-bastiodon-species.json'), PosixPath('pokemons/411-bastiodon.json')]
# Serializing files: [PosixPath('pokemons/412-burmy.json'), PosixPath('pokemons/412-burmy-species.json')]
# Serializing files: [PosixPath('pokemons/416-vespiquen.json'), PosixPath('pokemons/416-vespiquen-species.json')]
# Serializing files: [PosixPath('pokemons/426-drifblim-species.json'), PosixPath('pokemons/426-drifblim.json')]
# Serializing files: [PosixPath('pokemons/414-mothim-species.json'), PosixPath('pokemons/414-mothim.json')]
# Serializing files: [PosixPath('pokemons/410-shieldon.json'), PosixPath('pokemons/410-shieldon-species.json')]
# Serializing files: [PosixPath('pokemons/418-buizel.json'), PosixPath('pokemons/418-buizel-species.json')]
# Serializing files: [PosixPath('pokemons/413-wormadam-plant-species.json'), PosixPath('pokemons/413-wormadam-plant.json')]
# Serializing files: [PosixPath('pokemons/415-combee.json'), PosixPath('pokemons/415-combee-species.json')]
# Serializing files: [PosixPath('pokemons/417-pachirisu.json'), PosixPath('pokemons/417-pachirisu-species.json')]
# Serializing files: [PosixPath('pokemons/421-cherrim-species.json'), PosixPath('pokemons/421-cherrim.json')]
# Serializing files: [PosixPath('pokemons/425-drifloon.json'), PosixPath('pokemons/425-drifloon-species.json')]
# Serializing files: [PosixPath('pokemons/420-cherubi-species.json'), PosixPath('pokemons/420-cherubi.json')]
# Serializing files: [PosixPath('pokemons/422-shellos.json'), PosixPath('pokemons/422-shellos-species.json')]
# Serializing files: [PosixPath('pokemons/423-gastrodon-species.json'), PosixPath('pokemons/423-gastrodon.json')]
# Serializing files: [PosixPath('pokemons/434-stunky-species.json'), PosixPath('pokemons/434-stunky.json')]
# Serializing files: [PosixPath('pokemons/419-floatzel-species.json'), PosixPath('pokemons/419-floatzel.json')]
# Serializing files: [PosixPath('pokemons/431-glameow-species.json'), PosixPath('pokemons/431-glameow.json')]
# Serializing files: [PosixPath('pokemons/428-lopunny.json'), PosixPath('pokemons/428-lopunny-species.json')]
# Serializing files: [PosixPath('pokemons/435-skuntank.json'), PosixPath('pokemons/435-skuntank-species.json')]
# Serializing files: [PosixPath('pokemons/427-buneary-species.json'), PosixPath('pokemons/427-buneary.json')]
# Serializing files: [PosixPath('pokemons/437-bronzong.json'), PosixPath('pokemons/437-bronzong-species.json')]
# Serializing files: [PosixPath('pokemons/429-mismagius.json'), PosixPath('pokemons/429-mismagius-species.json')]
# Serializing files: [PosixPath('pokemons/444-gabite-species.json'), PosixPath('pokemons/444-gabite.json')]
# Serializing files: [PosixPath('pokemons/430-honchkrow.json'), PosixPath('pokemons/430-honchkrow-species.json')]
# Serializing files: [PosixPath('pokemons/424-ambipom-species.json'), PosixPath('pokemons/424-ambipom.json')]
# Serializing files: [PosixPath('pokemons/445-garchomp-species.json'), PosixPath('pokemons/445-garchomp.json')]
# Serializing files: [PosixPath('pokemons/443-gible.json'), PosixPath('pokemons/443-gible-species.json')]
# Serializing files: [PosixPath('pokemons/436-bronzor-species.json'), PosixPath('pokemons/436-bronzor.json')]
# Serializing files: [PosixPath('pokemons/438-bonsly-species.json'), PosixPath('pokemons/438-bonsly.json')]
# Serializing files: [PosixPath('pokemons/433-chingling.json'), PosixPath('pokemons/433-chingling-species.json')]
# Serializing files: [PosixPath('pokemons/439-mime-jr-species.json'), PosixPath('pokemons/439-mime-jr.json')]
# Serializing files: [PosixPath('pokemons/432-purugly-species.json'), PosixPath('pokemons/432-purugly.json')]
# Serializing files: [PosixPath('pokemons/440-happiny.json'), PosixPath('pokemons/440-happiny-species.json')]
# Serializing files: [PosixPath('pokemons/441-chatot-species.json'), PosixPath('pokemons/441-chatot.json')]
# ...
# Serializing files: [PosixPath('pokemons/888-zacian.json'), PosixPath('pokemons/888-zacian-species.json')]
# Serializing files: [PosixPath('pokemons/885-dreepy.json'), PosixPath('pokemons/885-dreepy-species.json')]
# Serializing files: [PosixPath('pokemons/887-dragapult-species.json'), PosixPath('pokemons/887-dragapult.json')]
# Serializing files: [PosixPath('pokemons/886-drakloak.json'), PosixPath('pokemons/886-drakloak-species.json')]
# Serializing files: [PosixPath('pokemons/891-kubfu.json'), PosixPath('pokemons/891-kubfu-species.json')]
# Serializing files: [PosixPath('pokemons/892-urshifu-single-strike.json'), PosixPath('pokemons/892-urshifu-single-strike-species.json')]
# Serializing files: [PosixPath('pokemons/889-zamazenta.json'), PosixPath('pokemons/889-zamazenta-species.json')]
# Serializing files: [PosixPath('pokemons/890-eternatus-species.json'), PosixPath('pokemons/890-eternatus.json')]
# Serializing files: [PosixPath('pokemons/893-zarude.json'), PosixPath('pokemons/893-zarude-species.json')]
# Serializing files: [PosixPath('pokemons/896-glastrier-species.json'), PosixPath('pokemons/896-glastrier.json')]
# Serializing files: [PosixPath('pokemons/897-spectrier.json'), PosixPath('pokemons/897-spectrier-species.json')]
# Serializing files: [PosixPath('pokemons/900-kleavor-species.json'), PosixPath('pokemons/900-kleavor.json')]
# Serializing files: [PosixPath('pokemons/898-calyrex-species.json'), PosixPath('pokemons/898-calyrex.json')]
# Serializing files: [PosixPath('pokemons/895-regidrago-species.json'), PosixPath('pokemons/895-regidrago.json')]
# Serializing files: [PosixPath('pokemons/894-regieleki-species.json'), PosixPath('pokemons/894-regieleki.json')]
# Serializing files: [PosixPath('pokemons/903-sneasler-species.json'), PosixPath('pokemons/903-sneasler.json')]
# Serializing files: [PosixPath('pokemons/901-ursaluna-species.json'), PosixPath('pokemons/901-ursaluna.json')]
# Serializing files: [PosixPath('pokemons/902-basculegion-male.json'), PosixPath('pokemons/902-basculegion-male-species.json')]
# Serializing files: [PosixPath('pokemons/904-overqwil.json'), PosixPath('pokemons/904-overqwil-species.json')]
# Serializing files: [PosixPath('pokemons/899-wyrdeer.json'), PosixPath('pokemons/899-wyrdeer-species.json')]
# Serializing files: [PosixPath('pokemons/907-floragato-species.json'), PosixPath('pokemons/907-floragato.json')]
# Serializing files: [PosixPath('pokemons/905-enamorus-incarnate-species.json'), PosixPath('pokemons/905-enamorus-incarnate.json')]
# Serializing files: [PosixPath('pokemons/913-quaxwell.json'), PosixPath('pokemons/913-quaxwell-species.json')]
# Serializing files: [PosixPath('pokemons/910-crocalor.json'), PosixPath('pokemons/910-crocalor-species.json')]
# Serializing files: [PosixPath('pokemons/908-meowscarada.json'), PosixPath('pokemons/908-meowscarada-species.json')]
# Serializing files: [PosixPath('pokemons/917-tarountula-species.json'), PosixPath('pokemons/917-tarountula.json')]
# Serializing files: [PosixPath('pokemons/906-sprigatito-species.json'), PosixPath('pokemons/906-sprigatito.json')]
# Serializing files: [PosixPath('pokemons/911-skeledirge-species.json'), PosixPath('pokemons/911-skeledirge.json')]
# Serializing files: [PosixPath('pokemons/916-oinkologne-male-species.json'), PosixPath('pokemons/916-oinkologne-male.json')]
# Serializing files: [PosixPath('pokemons/914-quaquaval.json'), PosixPath('pokemons/914-quaquaval-species.json')]
# Serializing files: [PosixPath('pokemons/909-fuecoco-species.json'), PosixPath('pokemons/909-fuecoco.json')]
# Serializing files: [PosixPath('pokemons/922-pawmo.json'), PosixPath('pokemons/922-pawmo-species.json')]
# Serializing files: [PosixPath('pokemons/912-quaxly.json'), PosixPath('pokemons/912-quaxly-species.json')]
# Serializing files: [PosixPath('pokemons/920-lokix-species.json'), PosixPath('pokemons/920-lokix.json')]
# Serializing files: [PosixPath('pokemons/915-lechonk-species.json'), PosixPath('pokemons/915-lechonk.json')]
# Serializing files: [PosixPath('pokemons/924-tandemaus.json'), PosixPath('pokemons/924-tandemaus-species.json')]
# Serializing files: [PosixPath('pokemons/918-spidops-species.json'), PosixPath('pokemons/918-spidops.json')]
# Serializing files: [PosixPath('pokemons/923-pawmot-species.json'), PosixPath('pokemons/923-pawmot.json')]
# Serializing files: [PosixPath('pokemons/921-pawmi-species.json'), PosixPath('pokemons/921-pawmi.json')]
# Serializing files: [PosixPath('pokemons/926-fidough-species.json'), PosixPath('pokemons/926-fidough.json')]
# Serializing files: [PosixPath('pokemons/919-nymble.json'), PosixPath('pokemons/919-nymble-species.json')]
# Serializing files: [PosixPath('pokemons/932-nacli-species.json'), PosixPath('pokemons/932-nacli.json')]
# Serializing files: [PosixPath('pokemons/927-dachsbun-species.json'), PosixPath('pokemons/927-dachsbun.json')]
# Serializing files: [PosixPath('pokemons/929-dolliv.json'), PosixPath('pokemons/929-dolliv-species.json')]
# Serializing files: [PosixPath('pokemons/931-squawkabilly-green-plumage.json'), PosixPath('pokemons/931-squawkabilly-green-plumage-species.json')]
# Serializing files: [PosixPath('pokemons/925-maushold-family-of-four-species.json'), PosixPath('pokemons/925-maushold-family-of-four.json')]
# Serializing files: [PosixPath('pokemons/930-arboliva-species.json'), PosixPath('pokemons/930-arboliva.json')]
# Serializing files: [PosixPath('pokemons/928-smoliv-species.json'), PosixPath('pokemons/928-smoliv.json')]
# Serializing files: [PosixPath('pokemons/937-ceruledge-species.json'), PosixPath('pokemons/937-ceruledge.json')]
# Serializing files: [PosixPath('pokemons/936-armarouge-species.json'), PosixPath('pokemons/936-armarouge.json')]
# Serializing files: [PosixPath('pokemons/933-naclstack.json'), PosixPath('pokemons/933-naclstack-species.json')]
# Serializing files: [PosixPath('pokemons/943-mabosstiff-species.json'), PosixPath('pokemons/943-mabosstiff.json')]
# Serializing files: [PosixPath('pokemons/939-bellibolt.json'), PosixPath('pokemons/939-bellibolt-species.json')]
# Serializing files: [PosixPath('pokemons/934-garganacl.json'), PosixPath('pokemons/934-garganacl-species.json')]
# Serializing files: [PosixPath('pokemons/940-wattrel-species.json'), PosixPath('pokemons/940-wattrel.json')]
# Serializing files: [PosixPath('pokemons/935-charcadet-species.json'), PosixPath('pokemons/935-charcadet.json')]
# Serializing files: [PosixPath('pokemons/942-maschiff-species.json'), PosixPath('pokemons/942-maschiff.json')]
# Serializing files: [PosixPath('pokemons/941-kilowattrel-species.json'), PosixPath('pokemons/941-kilowattrel.json')]
# Serializing files: [PosixPath('pokemons/938-tadbulb-species.json'), PosixPath('pokemons/938-tadbulb.json')]
# Serializing files: [PosixPath('pokemons/946-bramblin-species.json'), PosixPath('pokemons/946-bramblin.json')]
# Serializing files: [PosixPath('pokemons/952-scovillain.json'), PosixPath('pokemons/952-scovillain-species.json')]
# Serializing files: [PosixPath('pokemons/945-grafaiai-species.json'), PosixPath('pokemons/945-grafaiai.json')]
# Serializing files: [PosixPath('pokemons/947-brambleghast.json'), PosixPath('pokemons/947-brambleghast-species.json')]
# Serializing files: [PosixPath('pokemons/949-toedscruel.json'), PosixPath('pokemons/949-toedscruel-species.json')]
# Serializing files: [PosixPath('pokemons/948-toedscool-species.json'), PosixPath('pokemons/948-toedscool.json')]
# Serializing files: [PosixPath('pokemons/944-shroodle.json'), PosixPath('pokemons/944-shroodle-species.json')]
# Serializing files: [PosixPath('pokemons/950-klawf.json'), PosixPath('pokemons/950-klawf-species.json')]
# Serializing files: [PosixPath('pokemons/954-rabsca-species.json'), PosixPath('pokemons/954-rabsca.json')]
# Serializing files: [PosixPath('pokemons/953-rellor.json'), PosixPath('pokemons/953-rellor-species.json')]
# Serializing files: [PosixPath('pokemons/951-capsakid.json'), PosixPath('pokemons/951-capsakid-species.json')]
# Serializing files: [PosixPath('pokemons/955-flittle.json'), PosixPath('pokemons/955-flittle-species.json')]
# Serializing files: [PosixPath('pokemons/961-wugtrio-species.json'), PosixPath('pokemons/961-wugtrio.json')]
# Serializing files: [PosixPath('pokemons/958-tinkatuff.json'), PosixPath('pokemons/958-tinkatuff-species.json')]
# Serializing files: [PosixPath('pokemons/957-tinkatink-species.json'), PosixPath('pokemons/957-tinkatink.json')]
# Serializing files: [PosixPath('pokemons/959-tinkaton-species.json'), PosixPath('pokemons/959-tinkaton.json')]
# Serializing files: [PosixPath('pokemons/956-espathra-species.json'), PosixPath('pokemons/956-espathra.json')]
# Serializing files: [PosixPath('pokemons/966-revavroom-species.json'), PosixPath('pokemons/966-revavroom.json')]
# Serializing files: [PosixPath('pokemons/969-glimmet-species.json'), PosixPath('pokemons/969-glimmet.json')]
# Serializing files: [PosixPath('pokemons/971-greavard.json'), PosixPath('pokemons/971-greavard-species.json')]
# Serializing files: [PosixPath('pokemons/963-finizen.json'), PosixPath('pokemons/963-finizen-species.json')]
# Serializing files: [PosixPath('pokemons/962-bombirdier.json'), PosixPath('pokemons/962-bombirdier-species.json')]
# Serializing files: [PosixPath('pokemons/964-palafin-zero-species.json'), PosixPath('pokemons/964-palafin-zero.json')]
# Serializing files: [PosixPath('pokemons/960-wiglett-species.json'), PosixPath('pokemons/960-wiglett.json')]
# Serializing files: [PosixPath('pokemons/975-cetitan.json'), PosixPath('pokemons/975-cetitan-species.json')]
# Serializing files: [PosixPath('pokemons/978-tatsugiri-curly.json'), PosixPath('pokemons/978-tatsugiri-curly-species.json')]
# Serializing files: [PosixPath('pokemons/965-varoom.json'), PosixPath('pokemons/965-varoom-species.json')]
# Serializing files: [PosixPath('pokemons/967-cyclizar-species.json'), PosixPath('pokemons/967-cyclizar.json')]
# Serializing files: [PosixPath('pokemons/968-orthworm-species.json'), PosixPath('pokemons/968-orthworm.json')]
# Serializing files: [PosixPath('pokemons/970-glimmora.json'), PosixPath('pokemons/970-glimmora-species.json')]
# Serializing files: [PosixPath('pokemons/973-flamigo.json'), PosixPath('pokemons/973-flamigo-species.json')]
# Serializing files: [PosixPath('pokemons/974-cetoddle.json'), PosixPath('pokemons/974-cetoddle-species.json')]
# Serializing files: [PosixPath('pokemons/979-annihilape.json'), PosixPath('pokemons/979-annihilape-species.json')]
# Serializing files: [PosixPath('pokemons/972-houndstone-species.json'), PosixPath('pokemons/972-houndstone.json')]
# Serializing files: [PosixPath('pokemons/977-dondozo.json'), PosixPath('pokemons/977-dondozo-species.json')]
# Serializing files: [PosixPath('pokemons/976-veluza.json'), PosixPath('pokemons/976-veluza-species.json')]
# Serializing files: [PosixPath('pokemons/981-farigiraf-species.json'), PosixPath('pokemons/981-farigiraf.json')]
# Serializing files: [PosixPath('pokemons/988-slither-wing-species.json'), PosixPath('pokemons/988-slither-wing.json')]
# Serializing files: [PosixPath('pokemons/984-great-tusk-species.json'), PosixPath('pokemons/984-great-tusk.json')]
# Serializing files: [PosixPath('pokemons/980-clodsire-species.json'), PosixPath('pokemons/980-clodsire.json')]
# Serializing files: [PosixPath('pokemons/983-kingambit-species.json'), PosixPath('pokemons/983-kingambit.json')]
# Serializing files: [PosixPath('pokemons/985-scream-tail-species.json'), PosixPath('pokemons/985-scream-tail.json')]
# Serializing files: [PosixPath('pokemons/982-dudunsparce-two-segment.json'), PosixPath('pokemons/982-dudunsparce-two-segment-species.json')]
# Serializing files: [PosixPath('pokemons/993-iron-jugulis-species.json'), PosixPath('pokemons/993-iron-jugulis.json')]
# Serializing files: [PosixPath('pokemons/986-brute-bonnet-species.json'), PosixPath('pokemons/986-brute-bonnet.json')]
# Serializing files: [PosixPath('pokemons/987-flutter-mane.json'), PosixPath('pokemons/987-flutter-mane-species.json')]
# Serializing files: [PosixPath('pokemons/989-sandy-shocks.json'), PosixPath('pokemons/989-sandy-shocks-species.json')]
# Serializing files: [PosixPath('pokemons/991-iron-bundle-species.json'), PosixPath('pokemons/991-iron-bundle.json')]
# Serializing files: [PosixPath('pokemons/996-frigibax.json'), PosixPath('pokemons/996-frigibax-species.json')]
# Serializing files: [PosixPath('pokemons/990-iron-treads-species.json'), PosixPath('pokemons/990-iron-treads.json')]
# Serializing files: [PosixPath('pokemons/992-iron-hands.json'), PosixPath('pokemons/992-iron-hands-species.json')]
# Serializing files: [PosixPath('pokemons/997-arctibax-species.json'), PosixPath('pokemons/997-arctibax.json')]
# Serializing files: [PosixPath('pokemons/998-baxcalibur-species.json'), PosixPath('pokemons/998-baxcalibur.json')]
# Serializing files: [PosixPath('pokemons/994-iron-moth-species.json'), PosixPath('pokemons/994-iron-moth.json')]
# Serializing files: [PosixPath('pokemons/995-iron-thorns.json'), PosixPath('pokemons/995-iron-thorns-species.json')]
# Serializing files: [PosixPath('pokemons/999-gimmighoul.json'), PosixPath('pokemons/999-gimmighoul-species.json')]
# Serializing files: [PosixPath('pokemons/1001-wo-chien.json'), PosixPath('pokemons/1001-wo-chien-species.json')]
# Serializing files: [PosixPath('pokemons/1000-gholdengo.json'), PosixPath('pokemons/1000-gholdengo-species.json')]
# Serializing files: [PosixPath('pokemons/1006-iron-valiant.json'), PosixPath('pokemons/1006-iron-valiant-species.json')]
# Serializing files: [PosixPath('pokemons/1003-ting-lu-species.json'), PosixPath('pokemons/1003-ting-lu.json')]
# Serializing files: [PosixPath('pokemons/1002-chien-pao-species.json'), PosixPath('pokemons/1002-chien-pao.json')]
# Serializing files: [PosixPath('pokemons/1005-roaring-moon.json'), PosixPath('pokemons/1005-roaring-moon-species.json')]
# Serializing files: [PosixPath('pokemons/1004-chi-yu-species.json'), PosixPath('pokemons/1004-chi-yu.json')]
# Serializing files: [PosixPath('pokemons/1009-walking-wake.json'), PosixPath('pokemons/1009-walking-wake-species.json')]
# Serializing files: [PosixPath('pokemons/1011-dipplin.json'), PosixPath('pokemons/1011-dipplin-species.json')]
# Serializing files: [PosixPath('pokemons/1007-koraidon.json'), PosixPath('pokemons/1007-koraidon-species.json')]
# Serializing files: [PosixPath('pokemons/1010-iron-leaves.json'), PosixPath('pokemons/1010-iron-leaves-species.json')]
# Serializing files: [PosixPath('pokemons/1008-miraidon-species.json'), PosixPath('pokemons/1008-miraidon.json')]
# Serializing files: [PosixPath('pokemons/1016-fezandipiti.json'), PosixPath('pokemons/1016-fezandipiti-species.json')]
# Serializing files: [PosixPath('pokemons/1015-munkidori.json'), PosixPath('pokemons/1015-munkidori-species.json')]
# Serializing files: [PosixPath('pokemons/1017-ogerpon.json'), PosixPath('pokemons/1017-ogerpon-species.json')]
# Serializing files: [PosixPath('pokemons/1014-okidogi-species.json'), PosixPath('pokemons/1014-okidogi.json')]
# Serializing files: [PosixPath('pokemons/1012-poltchageist-species.json'), PosixPath('pokemons/1012-poltchageist.json')]
# Serializing files: [PosixPath('pokemons/1013-sinistcha.json'), PosixPath('pokemons/1013-sinistcha-species.json')]
# Serializing files: [PosixPath('pokemons/1019-hydrapple-species.json'), PosixPath('pokemons/1019-hydrapple.json')]
# Serializing files: [PosixPath('pokemons/1024-terapagos-species.json'), PosixPath('pokemons/1024-terapagos.json')]
# Serializing files: [PosixPath('pokemons/1020-gouging-fire.json'), PosixPath('pokemons/1020-gouging-fire-species.json')]
# Serializing files: [PosixPath('pokemons/1023-iron-crown-species.json'), PosixPath('pokemons/1023-iron-crown.json')]
# Serializing files: [PosixPath('pokemons/1025-pecharunt-species.json'), PosixPath('pokemons/1025-pecharunt.json')]
# Serializing files: [PosixPath('pokemons/1018-archaludon-species.json'), PosixPath('pokemons/1018-archaludon.json')]
# Serializing files: [PosixPath('pokemons/1022-iron-boulder-species.json'), PosixPath('pokemons/1022-iron-boulder.json')]
# Serializing files: [PosixPath('pokemons/1021-raging-bolt.json'), PosixPath('pokemons/1021-raging-bolt-species.json')]
# Serialized 1025 Pokémon.

# %% [markdown]
# # Data to DataFrame

# %%
import pandas as pd

# Convert the list of Pokemon objects to a DataFrame.
df = pd.DataFrame(results)
print(df.head())
# Out:
#    id        name  type1   type2  height  weight  color  gen  is_legendary
# 0   1   bulbasaur  grass  poison       7      69  green    1         False
# 1   2     ivysaur  grass  poison      10     130  green    1         False
# 2   3    venusaur  grass  poison      20    1000  green    1         False
# 3   4  charmander   fire    None       6      85    red    1         False
# 4   5  charmeleon   fire    None      11     190    red    1         False

# %% [markdown]
# # CSV Export

# %%
df.to_csv("pokemon_data.csv", index=False)
